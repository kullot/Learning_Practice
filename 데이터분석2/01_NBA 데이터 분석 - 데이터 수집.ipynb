# %%
import pandas as pd

# %% [markdown]
# ### 데이터 읽어오기
# - 웹 문서에서 데이터를 가져오고자 한다.
# - 원하는 데이터가 있는 곳의 html tag가 table 이라면 데이터 프레임으로 바로 생성이 가능하다.

# %%
# 읽어올 페이지의 주소
site = [
    'https://www.basketball-reference.com/leagues/NBA_2018_games-october.html',
    'https://www.basketball-reference.com/leagues/NBA_2018_games-november.html',
    'https://www.basketball-reference.com/leagues/NBA_2018_games-december.html',
    'https://www.basketball-reference.com/leagues/NBA_2018_games-january.html',
    'https://www.basketball-reference.com/leagues/NBA_2018_games-february.html',
    'https://www.basketball-reference.com/leagues/NBA_2018_games-march.html',
    'https://www.basketball-reference.com/leagues/NBA_2018_games-april.html',
    'https://www.basketball-reference.com/leagues/NBA_2018_games-may.html',
    'https://www.basketball-reference.com/leagues/NBA_2018_games-june.html',
]

# %%
# 지정된 웹 문서를 통해 데이터 프레임을 생성한다.
# read_html : 지정된 웹페이지에서 table 태그를 이용해 데이터프레임을 생성한다.
# 하나의 html 문서안에는 table 태그가 다수가 있을 수 있으므로
# table 태그 하나당 하나의 데이터 프레임이 생성되고
# 데이터 프레임들이 리스트에 담겨져서 반환된다. 
tables = pd.read_html(site[0])
tables[0]
# Out:
#                   Date Start (ET)        Visitor/Neutral  PTS  \
# 0    Tue, Oct 17, 2017      8:01p         Boston Celtics   99
# 1    Tue, Oct 17, 2017     10:30p        Houston Rockets  122
# 2    Wed, Oct 18, 2017      7:00p      Charlotte Hornets   90
# 3    Wed, Oct 18, 2017      7:00p          Brooklyn Nets  131
# 4    Wed, Oct 18, 2017      7:00p             Miami Heat  109
# ..                 ...        ...                    ...  ...
# 99   Mon, Oct 30, 2017     10:30p  Golden State Warriors  141
# 100  Tue, Oct 31, 2017      7:00p       Sacramento Kings   83
# 101  Tue, Oct 31, 2017      7:30p           Phoenix Suns  122
# 102  Tue, Oct 31, 2017      8:00p  Oklahoma City Thunder  110
# 103  Tue, Oct 31, 2017     10:30p        Detroit Pistons   93
#
#               Home/Neutral  PTS.1 Unnamed: 6 Unnamed: 7  Attend.  \
# 0      Cleveland Cavaliers    102  Box Score        NaN    20562
# 1    Golden State Warriors    121  Box Score        NaN    19596
# 2          Detroit Pistons    102  Box Score        NaN    20491
# 3           Indiana Pacers    140  Box Score        NaN    15008
# 4            Orlando Magic    116  Box Score        NaN    18846
# ..                     ...    ...        ...        ...      ...
# 99    Los Angeles Clippers    113  Box Score        NaN    19068
# 100         Indiana Pacers    101  Box Score        NaN    12245
# 101          Brooklyn Nets    114  Box Score        NaN    12936
# 102        Milwaukee Bucks     91  Box Score        NaN    16713
# 103     Los Angeles Lakers    113  Box Score        NaN    17569
#
#                          Arena  Notes
# 0          Quicken Loans Arena    NaN
# 1                 Oracle Arena    NaN
# 2         Little Caesars Arena    NaN
# 3      Bankers Life Fieldhouse    NaN
# 4                 Amway Center    NaN
# ..                         ...    ...
# 99              STAPLES Center    NaN
# 100    Bankers Life Fieldhouse    NaN
# 101            Barclays Center    NaN
# 102  BMO Harris Bradley Center    NaN
# 103             STAPLES Center    NaN
#
# [104 rows x 11 columns]

# %%
# 데이터 프레임을 담을 리스트
df_list = []
# 사이트의 주소 만큼 반복한다.
for s1 in site :
    # 해당 페이지에서 데이터 프레임들을 가져온다.
    df_list2 = pd.read_html(s1)
    # 첫 번째 데이터프레임을 추출하여 리스트에 담는다.
    df_list.append(df_list2[0])

# %%
# 모은 데이터 프레임들을 하나의 데이터프레임으로 합쳐준다.
df1 = pd.concat(df_list)
# 인덱스를 리셋한다.
df1.reset_index(drop=True, inplace=True)
df1
# Out:
#                    Date Start (ET)        Visitor/Neutral  PTS  \
# 0     Tue, Oct 17, 2017      8:01p         Boston Celtics   99
# 1     Tue, Oct 17, 2017     10:30p        Houston Rockets  122
# 2     Wed, Oct 18, 2017      7:00p      Charlotte Hornets   90
# 3     Wed, Oct 18, 2017      7:00p          Brooklyn Nets  131
# 4     Wed, Oct 18, 2017      7:00p             Miami Heat  109
# ...                 ...        ...                    ...  ...
# 1308  Mon, May 28, 2018      9:00p  Golden State Warriors  101
# 1309  Thu, May 31, 2018      9:00p    Cleveland Cavaliers  114
# 1310   Sun, Jun 3, 2018      8:00p    Cleveland Cavaliers  103
# 1311   Wed, Jun 6, 2018      9:00p  Golden State Warriors  110
# 1312   Fri, Jun 8, 2018      9:00p  Golden State Warriors  108
#
#                Home/Neutral PTS.1 Unnamed: 6 Unnamed: 7 Attend.  \
# 0       Cleveland Cavaliers   102  Box Score        NaN   20562
# 1     Golden State Warriors   121  Box Score        NaN   19596
# 2           Detroit Pistons   102  Box Score        NaN   20491
# 3            Indiana Pacers   140  Box Score        NaN   15008
# 4             Orlando Magic   116  Box Score        NaN   18846
# ...                     ...   ...        ...        ...     ...
# 1308        Houston Rockets    92  Box Score        NaN   18055
# 1309  Golden State Warriors   124  Box Score         OT   19596
# 1310  Golden State Warriors   122  Box Score        NaN   19596
# 1311    Cleveland Cavaliers   102  Box Score        NaN   20562
# 1312    Cleveland Cavaliers    85  Box Score        NaN   20562
#
#                         Arena Notes
# 0         Quicken Loans Arena   NaN
# 1                Oracle Arena   NaN
# 2        Little Caesars Arena   NaN
# 3     Bankers Life Fieldhouse   NaN
# 4                Amway Center   NaN
# ...                       ...   ...
# 1308            Toyota Center   NaN
# 1309             Oracle Arena   NaN
# 1310             Oracle Arena   NaN
# 1311      Quicken Loans Arena   NaN
# 1312      Quicken Loans Arena   NaN
#
# [1313 rows x 11 columns]

# %%
# 읽어온 데이터 프레임을 저장한다.
df1.to_csv('./data/NBA2028.csv', index=False)
