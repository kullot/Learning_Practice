# %% [markdown]
# ### 한국어 형태소 분석
# - 한국어로 된 문장에서 명사, 형용사, 조사 등을 추출하는 것.
# - 서울대학교, 트위터, 메타 등등에서 라이브러리를 만들어 배포하고 있다.
# - 현재 완벽하게 형태소를 분리해 낼 수 있는 라이브러리는 존재하지 않는다.
# - JDK 8 버전이 필요하다.

# %% [markdown]
# ### konlpy
# - nlpy 라는 라이브러리를 한국어에 맞게끔 만든 라이브러리
# - nlpy는 영어 문장의 형태소를 분리해내는 라이브러리
# - konlpy 라이브러이에는 서울대, 트위터, 메타 등등에서 만든 형태소 분리 라이브러리가 모두 포함되어 있다.
# - JDK 8 버전 설치가 필요하다.
#
# [JDK 설치]
# - 제공한 jdk 설치파일을 실행하여 설치한다
# - 설치 과정에서 변경하는 것은 없고 다음 다음 finish 만 잘 눌러준다.
#
# [윈도우에서 환경변수 설정]
# - jdk가 설치된 경로를 다른 프로그램들이 알 수 있도록 설정한다.
# - 먼저 jdk가 설치된 경로를 파악한다.
# - C:\Program Files\Java\jdk1.8.0_341
# - 탐색기의 내 PC에서 마우스 우클릭한다.
# - 우클릭해서 나오는 화면에서 고급시스템설정을 눌러준다.
# - 고급시스템설정 창에서 아래에 있는 환경변수설정 버튼을 눌러준다.
# - 환경변수 창에 있는 새로 만들기 버튼을 눌러준다.(위는 해당계정, 아래는 컴퓨터 전체)
# - 변수이름 : JAVA_HOME
# - 변수 값 : 아까 복사한 jdk의 경로
#
# [필요한 라이브러리 설치]
# - pip install konlpy==0.6.0
# - pip install jpype1
# - pip install jpype1-py3

# %% [markdown]
# ### 워드 클라우드를 사용하기 위한 설정
# - pip install pytagcloud
# - pip install pygame
# - pip install simplejson

# %%
# 기본
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
import shutil

# 경고 뜨지 않게...
import warnings
warnings.filterwarnings('ignore')

# 그래프 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['font.size'] = 16
plt.rcParams['figure.figsize'] = 20, 10
plt.rcParams['axes.unicode_minus'] = False
# 매직명령어 => 쥬피터노트북에서 그래프 삽입 기능 
# %matplotlib inline
# 글꼴 선명화 
# %config InlineBackend.figure_format = 'retina'

# 랜덤 모듈
import random

# 학습 모델 저장 및 복원
import pickle

# 딥러닝 라이브러리
import tensorflow as tf
# 신경망 모델을 관리하는 객체
from tensorflow.keras.models import Sequential
# 선형 회귀 레이어
from tensorflow.keras.layers import Dense
# 활성화 함수를 정의하는 객체
from tensorflow.keras.layers import Activation

# CNN : 커널을 통해 합성곱을 구하는 것. 이미지의 특징이 두드러 지게 한다.
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv1D

# MaxPooling : 커널내에서 가장 큰 값을 추출하는 방식으로 불필요한 부분을 제거한다.
from tensorflow.keras.layers import MaxPool2D
from tensorflow.keras.layers import MaxPool1D

# 1차원으로 변환하는 것
from tensorflow.keras.layers import Flatten

# Dropout : 이미자나 영상, 음파 등의 데이터는 오랫동안 학습을 진행 시켜야 한다.
# 하지만 너무 빨리 과적합이 발생되면 조기 중단 때문에 학습 횟수가 줄어들 수 있다.
# 이에 은닉의 노드를 일부 사용하지 않으므로써 과적합이 빨리 오는 것을 예방하고
# 오랫동안 학습이 가능하다.
from tensorflow.keras.layers import Dropout

# Embadding : 단어의 수를 조정한다.
from tensorflow.keras.layers import Embedding

# LSTM
from tensorflow.keras.layers import LSTM

# 원핫 인코딩을 수행하는 함수
from tensorflow.keras.utils import to_categorical

# 저장된 학습모델을 복원한다.
from tensorflow.keras.models import load_model

# 모델을 자동 저장한다.
from tensorflow.keras.callbacks import ModelCheckpoint
# 성능이 더이상 좋아지지 않을 경우 중단 시킨다.
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard

# 문장을 잘라준다.
from tensorflow.keras.preprocessing.text import Tokenizer
# 모든 문장 데이터의 단어 데이터의 수를 동일한 수로 맞춰준다.
from tensorflow.keras.preprocessing.sequence import pad_sequences
# 문자열을 가지고 단어 사전을 만들어준다.
from tensorflow.keras.preprocessing.text import text_to_word_sequence

# 평가함수
# 분류용
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

# 회귀용
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# 표준화
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
# 문자열 => 숫자
from sklearn.preprocessing import LabelEncoder

# 전체데이터를 학습용과 검증으로 나눈다.
from sklearn.model_selection import train_test_split

# 랜덤시드 설정
# 데이터를 랜덤하게 섞거나 가중치를 랜덤하게 설정하는 등..
# 작업에서 랜덤을 적용하는 경우가 더러 있다.
# 이에, 시드를 고정시킨다.
random_seed = 1
np.random.seed(random_seed)
random.seed(random_seed)
tf.random.set_seed(random_seed)

# 현재 프로젝트에서 GPU 메모리 사용을 필요한 만큼만 쓸 수 있도록 한다.
# 컴퓨터에 있는 GPU 정보들을 가져온다.

# gpus = tf.config.experimental.list_physical_devices('GPU')
# # gpu가 있다면...
# if len(gpus) > 0 :
#     try :
#         for gpu in gpus :
#             tf.config.experimental.set_memory_growth(gpu, True)
#     except RuntimeError as e :
#         print(e)

# %%
# 한국어 형태소 분석
from konlpy.tag import Okt, Hannanum, Kkma, Mecab, Komoran

# 워드 클라우드
from collections import Counter
import pytagcloud
from IPython.display import Image
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ### 형태소 분리 예제

# %%
a1 = '동해물과 백두산이 마르고 닳도록'

# %%
# 형태소 분석기 생성
tagger1 = Okt()
tagger2 = Kkma()
tagger3 = Hannanum()
tagger4 = Komoran()

print(tagger1.morphs(a1))
print(tagger2.morphs(a1))
print(tagger3.morphs(a1))
print(tagger4.morphs(a1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 # 형태소 분석기 생성
# ----> 2 tagger1 = Okt()
#       3 tagger2 = Kkma()
#       4 tagger3 = Hannanum()
#
# File ~\anaconda3\lib\site-packages\konlpy\tag\_okt.py:51, in Okt.__init__(self, jvmpath, max_heap_size)
#      49 def __init__(self, jvmpath=None, max_heap_size=1024):
#      50     if not jpype.isJVMStarted():
# ---> 51         jvm.init_jvm(jvmpath, max_heap_size)
#      53     oktJavaPackage = jpype.JPackage('kr.lucypark.okt')
#      54     OktInterfaceJavaClass = oktJavaPackage.OktInterface
#
# File ~\anaconda3\lib\site-packages\konlpy\jvm.py:64, in init_jvm(jvmpath, max_heap_size)
#      61     jvmpath = '%s/lib/jli/libjli.dylib' % jvmpath.split('/lib/')[0]
#      63 if jvmpath:
# ---> 64     jpype.startJVM(jvmpath, '-Dfile.encoding=UTF8',
#      65                             '-ea', '-Xmx{}m'.format(max_heap_size),
#      66                             classpath=classpath,
#      67                             # convertStrings=True,
#      68                             )
#      69 else:
#      70     raise ValueError("Please specify the JVM path.")
#
# TypeError: startJVM() got an unexpected keyword argument 'classpath'

# %%
# 명사만 추출
print(tagger1.nouns(a1))
print(tagger2.nouns(a1))
print(tagger3.nouns(a1))
print(tagger4.nouns(a1))
# Out:
# ['해물', '백두산', '마르고']
# ['물', '백두산']
# ['동해물', '백두산']
# ['동해물과 백두산이', '마르고']

# %%
a1 = '똑바로 읽어도 우영우, 거꾸로 읽어도 우영우. 기러기, 토마토, 스위스'

# %%
print(tagger1.morphs(a1))
print(tagger2.morphs(a1))
print(tagger3.morphs(a1))
print(tagger4.morphs(a1))
# Out:
# ['똑바로', '읽어도', '우영', '우', ',', '거꾸로', '읽어도', '우영', '우', '.', '기러기', ',', '토마토', ',', '스위스']
# ['똑바로', '읽', '어도', '우', '영우', ',', '거꾸로', '읽', '어도', '우영', '우', '.', '기러기', ',', '토마토', ',', '스위스']
# ['똑바로', '읽', '어도', '우영우,', '거꾸로', '읽', '어도', '우영우', '.', '기러기', ',', '토마토', ',', '스위스']
# ['똑바로', '읽', '어도', '우영', '우', ',', '거꾸로', '읽', '어도', '우영', '우', '.', '기러기', ',', '토마토', ',', '스위스']

# %%
# 명사만 추출
print(tagger1.nouns(a1))
print(tagger2.nouns(a1))
print(tagger3.nouns(a1))
print(tagger4.nouns(a1))
# Out:
# ['똑바로', '우영', '거꾸로', '우영', '기러기', '토마토', '스위스']
# ['우', '우영우', '영우', '우영', '기러기', '토마토', '스위스']
# ['우영우,', '우영우', '기러기', '토마토', '스위스']
# ['우영', '우', '우영', '우', '기러기', '토마토', '스위스']

# %% [markdown]
# ### 데이터를 읽어온다.

# %%
df = pd.read_csv('./11_data.csv')
df
# Out:
#                                                  title  \
# 0                   손흥민 향해 '눈 찢기'한 男의 최후…"경기장 영구 출입금지"
# 1                                  손흥민 대신 히샬리송? 결국 골이다
# 2                       ‘수비 좀 해!’ 주장 요리스, 또 경기중 손흥민 질책
# 3                   [스잘알]손흥민vs요리스 충돌로 본 유럽축구 동료 간 주먹다짐
# 4                      손흥민이 아직도 무득점이라니…"몇 골 넣으면 달라질 것"
# ..                                                 ...
# 995                    이제 손흥민 경기도 유료채널로만… 토트넘-사우스햄튼전부터
# 996                 CBS전문가, EPL 올해의 선수로 손흥민 예측.."다크호스"
# 997                         두 번 울었던 손흥민, ‘삼세판 월드컵’은 웃자
# 998  [EPL개막특집]③손흥민, 득점왕 2연패 도전…홀란드, 살라, 누녜스, 케인 'EP...
# 999                 "손흥민보다 더 낫더라"…토트넘 레전드도 인정 "신입생 효과"
#
#                                            description
# 0    잉글랜드 프로축구 프리미어리그(EPL)에서 뛰는 손흥민(30·토트넘)에게 인종 차별...
# 1    손흥민(30·토트넘)의 시즌 초반 행보를 놓고 현지에서 또 말이 나오고 있다. 손흥...
# 2    잉글랜드 프로축구 프리미어리그 토트넘에서 뛰는 손흥민(30)이 팀의 주장이자 주전 ...
# 3    기사내용 요약 손흥민-요리스, 2020년 이어 최근에 또 경기 도중 언쟁 손흥민, ...
# 4    손흥민(토트넘)이 시즌 초반 어려움을 겪고 있다. 손흥민이 올 시즌 아직 득점을 올...
# ..                                                 ...
# 995  지난 시즌 '슈퍼 쏘니' 손흥민이 모하메드 살라와 공동 득점왕을 차지하면서 국내 축...
# 996  한 미국 매체의 전문가가 '손세이셔널' 손흥민(토트넘)을 2022~2023시즌 잉글...
# 997  손흥민(토트넘)은 이번엔 반드시 웃겠다는 각오다. 2014년 브라질, 2018년 러...
# 998  "인류가 달에 간 만큼 엄청난 일이다." 이영표 강원FC 대표이사(45)는 '후배'...
# 999  해리 케인이 득점을 올렸지만 손흥민과 데얀 쿨루셉스키를 필두로 한 공격력이 화끈하지...
#
# [1000 rows x 2 columns]

# %%
# 결측치 확인
df.isna().sum()
# Out:
# title          0
# description    0
# dtype: int64

# %% [markdown]
# ### 한글 정제

# %%
import re
# 주어진 문장에서 한글만 추출해 반환하는 함수
def text_cleaning(text): 
    # 한글 정규식(띄어쓰기, ㄱ ~ ㅣ, 가 ~ 힣)
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+')
    # 정규식에 위배되는 글자들은 길이가 0인 문자열로 변환한다.
    result = hangul.sub('', text)
    return result

# %%
a1 = '가나ㄱㄴab!@#324다라'
text_cleaning(a1)
# Out:
# '가나ㄱㄴ다라'

# %%
# 한글 정제
df['title'] = df['title'].apply(lambda x : text_cleaning(x))
df['description'] = df['description'].apply(lambda x : text_cleaning(x))
df
# Out:
#                                title  \
# 0       손흥민 향해 눈 찢기한 의 최후경기장 영구 출입금지
# 1                 손흥민 대신 히샬리송 결국 골이다
# 2         수비 좀 해 주장 요리스 또 경기중 손흥민 질책
# 3     스잘알손흥민요리스 충돌로 본 유럽축구 동료 간 주먹다짐
# 4       손흥민이 아직도 무득점이라니몇 골 넣으면 달라질 것
# ..                               ...
# 995    이제 손흥민 경기도 유료채널로만 토트넘사우스햄튼전부터
# 996          전문가  올해의 선수로 손흥민 예측다크호스
# 997          두 번 울었던 손흥민 삼세판 월드컵은 웃자
# 998  개막특집손흥민 득점왕 연패 도전홀란드 살라 누녜스 케인
# 999    손흥민보다 더 낫더라토트넘 레전드도 인정 신입생 효과
#
#                                            description
# 0    잉글랜드 프로축구 프리미어리그에서 뛰는 손흥민토트넘에게 인종 차별적 행위를 한 팬이...
# 1    손흥민토트넘의 시즌 초반 행보를 놓고 현지에서 또 말이 나오고 있다 손흥민은 지난 ...
# 2    잉글랜드 프로축구 프리미어리그 토트넘에서 뛰는 손흥민이 팀의 주장이자 주전 골키퍼인...
# 3    기사내용 요약 손흥민요리스 년 이어 최근에 또 경기 도중 언쟁 손흥민 년 함부르크 ...
# 4    손흥민토트넘이 시즌 초반 어려움을 겪고 있다 손흥민이 올 시즌 아직 득점을 올리지 ...
# ..                                                 ...
# 995  지난 시즌 슈퍼 쏘니 손흥민이 모하메드 살라와 공동 득점왕을 차지하면서 국내 축구 ...
# 996  한 미국 매체의 전문가가 손세이셔널 손흥민토트넘을 시즌 잉글랜드 프리미어리그 올해의...
# 997  손흥민토트넘은 이번엔 반드시 웃겠다는 각오다 년 브라질 년 러시아 대회에선 모두 조...
# 998  인류가 달에 간 만큼 엄청난 일이다 이영표 강원 대표이사는 후배 손흥민토트넘의 잉글...
# 999  해리 케인이 득점을 올렸지만 손흥민과 데얀 쿨루셉스키를 필두로 한 공격력이 화끈하지...
#
# [1000 rows x 2 columns]

# %%
# 모든 문장을 하나의 문장으로 합쳐준다.
title_corpus = ''.join(df['title'])
description_corpus = ''.join(df['description'])

# %%
# 손흥민을 삭제한다.
title_corpus = title_corpus.replace('손흥민', '')
description_corpus = description_corpus.replace('손흥민', '')

# %%
# 명사만 추출한다.
tagger = Okt()

title_nouns = tagger.nouns(title_corpus)
description_nouns = tagger.nouns(description_corpus)

# %%
print(description_nouns)
# Out:
# ['잉글랜드', '프로축구', '프리미어리그', '토트넘', '인종', '차별', '행위', '팬', '무기한', '당시', '이', '코너킥', '차기', '위해', '경기장', '구석', '이동', '남성', '관중석', '상의', '눈', '옆', '토트넘', '시즌', '초반', '행보', '현지', '또', '말', '은', '지난', '일한국', '시각', '영국', '런던', '토트넘', '홋스퍼', '스타디움', '잉글랜드', '프리미어리그', '라운드', '울버햄튼', '전', '잉글랜드', '프로축구', '프리미어리그', '토트넘', '이', '팀', '주장', '이자', '주전', '골키퍼', '위고', '리스', '프랑스', '경기', '도중', '또', '언쟁', '영국', '축구', '전문', '매체', '풋볼', '런던', '일', '과', '리스', '전날', '기사', '내용', '요약', '리스', '년', '최근', '또', '경기', '도중', '언쟁', '년', '함부르크', '시절', '동료', '발차기', '다툼', '구자철', '볼프스부르크', '때', '훈련', '동료', '주먹다짐', '사상', '최악', '동료', '난투극', '토트넘', '시즌', '초반', '어려움', '이', '시즌', '득점', '리지', '시즌', '잉글랜드', '프리미어리그', '라운드', '모두', '선발', '나선', '은', '도움', '기록', '뿐', '골', '지난', '나폴리', '토트넘', '황희', '찬', '울버햄프턴', '득점', '포', '가동', '김민재', '일', '지난', '시즌', '잉글랜드', '프리미어리그', '공동', '득점', '세계', '최고', '골잡', '중', '하나로', '은', '토트넘', '출신', '해설', '하라', '의', '교체', '대해', '아쉬움', '오하', '시간', '영국', '토크', '스포츠', '통해', '울버햄튼', '전', '의', '활약', '대한', '생각', '전', '은', '울버햄튼', '전', '선발', '출전', '팀', '토트넘', '레전드', '토트넘', '시즌', '초반', '부진', '지난', '시즌', '골로', '프리미어리그', '득점', '차지', '의', '출발', '삐걱', '대고', '은', '최근', '경기', '연속', '교체', '모습', '은', '잉글랜드', '프리미어리그', '토트넘', '홋스퍼', '이', '년', '동료', '골키퍼', '위고', '리스', '충돌', '경기', '중', '수비', '가담', '언쟁', '것', '영국', '매체', '풋볼', '런던', '이하', '한국', '시간', '과', '토트넘', '홋스퍼', '인종차별', '행위', '팬', '무기한', '경기장', '출입', '금지', '징계', '도중', '은', '첼시', '팬', '인종차별', '행위', '당시', '경기', '후반', '이', '코너킥', '차기', '위해', '이동', '때', '홋스퍼', '이', '소속', '팀', '주장', '위고', '리스', '프랑스', '골키퍼', '경기', '도중', '언쟁', '영국', '매체', '풋볼', '런던', '일한국', '시간', '과', '리스', '전날', '울버햄튼', '경기', '도중', '말다툼', '전', '토트넘', '빅클럽', '주전', '평가', '선수', '출신', '오언', '하그리브스', '일한국', '시간', '프리미어리그', '프로덕션', '출연', '골', '해리', '케인', '칭찬', '것', '기사', '내용', '요약', '첼시', '구단', '인종차별', '팬', '무기한', '경기장', '출입', '금지', '잉글랜드', '프로축구', '프리미어리그', '토트넘', '인종차별', '팬', '무기한', '경기장', '출입', '금지', '조처', '첼시', '구단', '년', '경기', '중', '차례', '크게', '충돌', '적', '과', '골키퍼', '위고', '리스', '토트넘', '울버햄튼', '전', '스로인', '오라', '야단', '말', '이', '이', '상황', '잉글랜드', '프로축구', '프리미어리그', '토트넘', '홋스퍼', '이', '팀', '동료', '주전', '골키퍼', '위고', '리스', '프랑스', '경기', '중', '언쟁', '영국', '축구', '전문', '매체', '풋볼', '런던', '일', '오전', '한국', '시간', '과', '리스', '토트넘', '이', '세', '경기', '무', '득점', '새', '시즌', '초반', '득점', '위용', '못', '은', '일한국', '시간', '영국', '런던', '토트넘', '훗스퍼', '스타디움', '울버햄튼', '시즌', '잉글랜드', '프리미어리그', '과', '리스', '이상', '토트넘', '또', '다시', '충돌', '이하', '한국', '시각', '영국', '축구', '전문', '매체', '풋볼', '런던', '과', '리스', '울버햄턴', '전', '서로', '언쟁', '보도', '토트넘', '일', '영국', '런던', '토트넘홋스퍼', '이', '시즌', '프리미어리그', '초반', '경기', '득점', '포', '가동', '영국', '현지', '신뢰', '감', '영국', '은', '일한국', '시간', '대한', '오언', '하그리브스', '인터뷰', '내용', '소개', '현역', '시절', '차세대', '꿈', '군', '초등학교', '고학년', '축구', '선수', '꿈', '고민', '또래', '친구', '달리', '저학년', '때', '수준', '키', '때문', '병원', '신장', '아동', '잉글랜드', '프리미어리그', '경기', '중', '선수', '토트넘', '인종', '차별', '첼시', '팬', '무기한', '경기장', '후반전', '이', '코너킥', '도중', '관중석', '팬', '눈', '옆', '동작', '취했다', '처벌', '선수', '잉글랜드', '프리미어리그', '경기', '중', '또', '인종차별', '피해', '서경덕', '교수', '전', '구단', '항의', '스포츠', '전문', '매체', '디애', '슬레', '일한국', '시간', '첼시', '토트넘', '경기', '잉글랜드', '프로축구', '프리미어리그', '활약', '토트넘', '인종', '차별', '팬', '무기한', '당시', '남성은', '후반', '분', '이', '코너킥', '차기', '위해', '코너', '플래그', '눈', '행위', '취했다', '잉글랜드', '프리미어리그', '첼시', '토트넘', '인종차별', '행위', '팬', '무기한', '출입', '금지', '경기', '이', '코너킥', '이동', '와중', '관중석', '상의', '탈의', '눈', '행동', '이', '첼시', '사진', '인스타그램', '토트넘', '이', '두', '경기', '연속', '교체', '것', '대해', '토트넘', '제이', '하라', '우려', '지난', '일', '스포', '티비', '뉴스', '보도', '오하', '일한국', '시간', '토트넘', '새', '시즌', '초반', '고전', '중이', '은', '일', '울버햄프턴', '전', '골', '사냥', '실패', '개막', '연기', '연속', '침묵', '한국', '선수', '두', '팀', '대결', '이', '분', '뒤', '황희', '찬', '선수', '향', '인종차별', '행위', '대해', '첼시', '구단', '해당', '팬', '영구', '출입', '금지', '조치', '것', '관련', '서경덕', '앞서', '스포츠', '매체', '디애슬래틱', '첼시', '지난', '일', '토트넘', '전', '향', '인종차별', '가능성', '잉글랜드', '프리미어리그', '득점', '토트넘', '안', '상대', '또', '다른', '국가대표', '측면', '날개', '선발', '출전', '이', '후반', '분', '교체', '때', '라운드', '누', '영국', '프리미어', ' ...

# %%
# 각 단어에 대한 빈도수를 계산한다.
title_count = Counter(title_nouns)
description_count = Counter(description_nouns)

print(title_count)
print('----------------')
print(description_count)
# Out:
# Counter({'첼시': 256, '토트넘': 251, '황희': 168, '인종차별': 168, '찬': 166, '골': 112, '전': 99, '팬': 98, '득점': 97, '시즌': 84, '첫': 75, '경기': 73, '울버햄튼': 72, '발롱도르': 69, '케인': 68, '더비': 64, '코리안': 58, '선발': 58, '후보': 57, '향': 56, '침묵': 54, '동료': 53, '눈': 52, '출입': 52, '금지': 52, '또': 48, '개막전': 48, '서경덕': 47, '평점': 47, '김민재': 43, '행위': 43, '조사': 39, '위': 39, '중계': 36, '교체': 34, '무기한': 34, '구단': 34, '도전': 34, '경기일정': 33, '무승부': 33, '리스': 32, '인': 32, '도움': 31, '선정': 28, '점': 26, '것': 25, '대결': 25, '선수': 25, '연속': 24, '처벌': 24, '분': 24, '년': 23, '벨레': 23, '수비': 22, '중': 22, '착수': 22, '항의': 21, '번': 21, '은': 20, '결승골': 20, '출전': 20, '나폴리': 20, '일': 20, '공격': 20, '메시': 20, '새': 20, '무산': 19, '은돔': 19, '포함': 19, '징계': 18, '명': 18, '임대': 18, '평가': 18, '경기장': 17, '충돌': 17, '골대': 17, '최고': 17, '발표': 17, '예상': 17, '영구': 16, '강력': 16, '조치': 16, '제임스': 16, '극적': 16, '주장': 15, '팀': 15, '레전드': 14, '공개': 14, '언쟁': 14, '치': 14, '개막': 14, '대응': 14, '먼저': 14, '오피': 14, '셜': 14, '가장': 14, '벤치': 14, '라인업': 14, '축구': 13, '아시아': 13, '과': 13, '교수': 13, '출격': 13, '이적': 13, '등': 13, '포인트': 13, '월드': 12, '전서': 12, '왜': 12, '두': 12, '유료': 12, '무관용': 12, '강타': 12, '최': 12, '승': 12, '누가': 12, '콘테': 12, '명단': 12, '활약': 12, '제외': 12, '언더웨어': 12, '의': 11, '클래스': 11, '리버풀': 11, '모독': 11, '승리': 11, '더': 11, '차별': 11, '사냥': 11, '동점골': 11, '사우샘프턴': 11, '무': 10, '울버햄프턴': 10, '불발': 10, '매체': 10, '인종': 10, '성명': 10, '절친': 10, '월드컵': 10, '이후': 10, '상대로': 10, '내': 10, '꽁꽁': 10, '캘빈': 10, '클라인': 10, '히샤를리송': 10, '안': 9, '언론': 9, '무료': 9, '공식': 9, '호골': 9, '후반': 9, '월': 9, '어시스트': 9, '대승': 9, '데뷔골': 8, '현지': 8, '전체': 8, '관심': 8, '수비수': 8, '호': 8, '코너킥': 8, '울버햄턴': 8, '못': 8, '확정': 8, '입': 8, '조준': 8, '속옷': 8, '기량': 8, '발탁': 8, '화보': 8, '스타': 8, '히샬리송': 7, '선례': 7, '슈팅': 7, '다시': 7, '관여': 7, '투입': 7, '앞': 7, '결승': 7, '경찰': 7, '스포츠': 7, '모습': 7, '부진': 7, '하나': 7, '페리': 7, '프리미어리그': 7, '이': 7, '장골': 7, '최종': 7, '정': 7, '로': 7, '극장': 7, '능력': 7, '임영웅': 7, '아웃': 6, '공격수': 6, '바보': 6, '피해': 6, '관중': 6, '경쟁': 6, '극찬': 6, '이번': 6, '쿠팡': 6, '플레이': 6, '기록': 6, '상대': 6, '순위': 6, '세븐일레븐': 6, '주말': 6, '시간': 6, '네이마르': 6, '환상': 6, '전망': 6, '쿨리': 6, '발리': 6, '광복절': 6, '추가': 6, '카타르': 6, '실점': 6, '아이유': 6, '번호': 6, '유럽': 5, '몇': 5, '도': 5, '분노': 5, '슛': 5, '걱정': 5, '리그': 5, '실패': 5, '영국': 5, '겨냥': 5, '뒤': 5, '효과': 5, '울브스': 5, '해리': 5, '세': 5, '신원': 5, '후': 5, '포': 5, '백업': 5, '최저': 5, '출시': 5, '견제': 5, '출발': 5, '리뷰': 5, '현장': 5, '듀오': 5, '주목': 5, '호날두': 5, '훈련': 5, '채널번호': 5, '한국': 5, '런던': 5, '게임': 5, '섹시': 5, '앰버': 5, '경쟁자': 5, '쿨': 5, '스키': 5, '랭킹': 5, '모델': 5, '엠버': 5, '해': 4, '해설': 4, '문제': 4, '집중': 4, '세리에': 4, '이유': 4, '데뷔': 4, '메일': 4, '속': 4, '시작': 4, '유효': 4, '단일': 4, '철퇴': 4, '채널': 4, '확인': 4, '개': 4, '예고': 4, '충격': 4, '투헬': 4, '선제골': 4, '제압': 4, '제스처': 4, '축포': 4, '전설': 4, '역대': 4, '주인공': 4, '그': 4, '볼': 4, '무패': 4, '돔': 4, '콜라보': 4, '비판': 4, '판정': 4, '행': 4, '누구': 4, '묶인': 4, '어디': 4, '보이': 4, '회': 4, '벤제마': 4, '유일': 4, '지난': 4, '성사': 4, '격돌': 4, '신고': 4, '감독': 4, '전반': 4, '합작': 4, '공': 4, '종료': 4, '역사': 4, '위위': 4, '억': 4, '수': 4, '혹평': 4, '칭찬': 4, '천적': 4, '달': 4, '완승': 4, '종합': 4, '홀란드': 4, '치명': 4, '전적': 4, '금융': 4, '광고': 4, '역전': 4, '서비스': 4, '좀': 3, '질책': 3, '스': 3, '완벽': 3, '출신': 3, '골키퍼': 3, '맨시티': 3, '주전': 3, '기자': 3, '꿈': 3, '징크스': 3, '정지': 3, '도중': 3, '언제': 3, '이슈': 3, '사람': 3, '무기': 3, '선배': 3, '코리언': 3, '베스트': 3, '격파': 3, '뻔': 3, '의미': 3, '발생': 3, '해당': 3, '당한': 3, '폭발': 3, '단짝': 3, '기여': 3, '논란': 3, '직면': 3, '아쉬움': 3, '듯': 3, '친구': 3, '골로': 3, '대기': 3, '마수': 3, '걸이': 3, '다음': 3, '상황': 3, '개봉': 3, '박두': 3, '계속': 3, '카': 3, '남자': 3, '프로': 3, '틴': 3, '속보': 3, '최하': 3, '선봉': 3, '임박': 3, '우도': 3, '가능성': 3, '역습': 3, '일침': 3, '해결': 3, '맨유': 3, '곧': 3, '나': 3, '스포': 3, '티비': 3, '나우': 3, '연패': 3, '춘천': 3, '손황': 3, '개인': 3, '중계방송': 3, '나혼산': 3, '수상': 3, '언급': 3, '생중계': 3, '맨': 3, '음료': 3, '생각': 3, '비난': 3, '비야레알': 3, '반박': 3, '서도': 3, '세트': 3, '피스': 3, '때': 3, '준비': 3, '동반': 3, '변화': 3, '카타르월드컵': 3, '핫': 3, '예측': 3, '옵션': 3, '열': 3, '몸값': 3, '라운드': 3, '캠페인': 3, '크로스': 3, '패션': 3, ...
# ----------------
# Counter({'토트넘': 1190, '첼시': 476, '프리미어리그': 474, '경기': 438, '이': 430, '시즌': 423, '은': 412, '잉글랜드': 389, '영국': 311, '일': 289, '득점': 274, '시간': 270, '인종차별': 262, '찬': 247, '황희': 245, '런던': 237, '지난': 218, '선수': 215, '팬': 204, '홋스퍼': 188, '분': 188, '케인': 181, '과': 178, '한국': 172, '전': 158, '골': 158, '일한국': 157, '선발': 153, '프로축구': 149, '축구': 137, '의': 129, '울버햄튼': 128, '팀': 127, '라운드': 126, '발롱도르': 126, '매체': 123, '행위': 116, '향': 114, '출전': 108, '후반': 107, '코너킥': 101, '해리': 97, '후보': 94, '활약': 90, '첫': 90, '년': 89, '중': 89, '사진': 89, '공격': 81, '두': 80, '기록': 79, '개막전': 78, '풋볼': 76, '대결': 72, '구단': 71, '리스': 70, '것': 70, '공격수': 69, '아시아': 68, '스포츠': 66, '프랑스': 65, '브리지': 64, '도중': 63, '이번': 63, '울버햄프턴': 62, '교체': 62, '오후': 60, '시': 60, '오른': 57, '대해': 56, '소속': 56, '스타디움': 55, '등': 54, '눈': 53, '나폴리': 53, '도움': 52, '개막': 52, '홈': 52, '리그': 51, '포인트': 51, '이동': 49, '시각': 49, '페리': 49, '더비': 49, '전문': 47, '김민재': 47, '수비': 47, '스탬퍼드': 47, '날': 46, '이하': 45, '번': 44, '가운데': 44, '그': 44, '데얀': 44, '통해': 43, '위해': 42, '동료': 42, '세계': 42, '상대로': 42, '코리안': 42, '사우샘프턴': 42, '왼쪽': 42, '수': 42, '클라인': 42, '또': 41, '상대': 41, '인': 41, '캘빈': 41, '현지': 40, '연속': 40, '침묵': 40, '포드': 40, '스키': 40, '새': 39, '최초': 39, '명': 39, '선정': 39, '일부': 38, '후': 38, '이름': 38, '위': 38, '은돔': 38, '벨레': 38, '경기장': 37, '보도': 37, '도전': 37, '최고': 36, '치': 36, '도': 36, '호': 36, '서경덕': 35, '기자': 35, '조사': 35, '평점': 35, '이자': 34, '대한': 34, '훗스퍼': 34, '교수': 34, '스탬': 34, '감독': 34, '홋스퍼이': 34, '주장': 33, '출신': 33, '포함': 33, '때': 32, '스': 32, '쿨': 31, '로': 31, '에르': 31, '주관': 31, '인종': 30, '무기한': 30, '차기': 30, '포': 30, '오전': 30, '이비': 30, '피해': 29, '전반': 29, '이후': 29, '쿨루셉스키': 29, '원': 29, '겨냥': 29, '차별': 28, '뒤': 28, '월': 28, '발표': 28, '슬레': 27, '이반': 27, '결승골': 27, '원정': 27, '점': 27, '연합뉴스': 27, '공식': 27, '못': 26, '측면': 26, '잉글리시': 26, '당시': 25, '위고': 25, '최근': 25, '공동': 25, '국가대표': 25, '이적': 25, '루셉': 24, '골키퍼': 23, '평가': 23, '관심': 23, '월드': 23, '관중석': 22, '모두': 22, '출입': 22, '금지': 22, '차례': 22, '세': 22, '개': 22, '논란': 22, '명단': 22, '언더웨어': 22, '내용': 21, '모습': 21, '가장': 21, '콘테': 21, '출처': 21, '피에르': 21, '제임스': 21, '언쟁': 20, '다시': 20, '울버햄턴': 20, '더': 20, '자신': 20, '축구선수': 20, '히샬리송': 20, '임대': 20, '리': 20, '벤탄쿠르': 20, '사냥': 19, '위치': 19, '대표팀': 19, '홈페이지': 19, '권위': 19, '남성': 18, '인스타그램': 18, '중인': 18, '발생': 18, '살라': 18, '지난해': 18, '승리': 18, '제스처': 18, '수비수': 18, '에밀': 18, '클래스': 18, '옆': 17, '초반': 17, '요약': 17, '차지': 17, '이상': 17, '행동': 17, '뉴스': 17, '전체': 17, '무산': 17, '치가': 17, '무승부': 17, '사건': 17, '맨체스터': 17, '브릿지': 17, '핫스퍼이': 17, '손': 17, '공개': 17, '기사': 16, '뿐': 16, '무': 16, '디애': 16, '가능성': 16, '슈팅': 16, '문제': 16, '유나이티드': 16, '소화': 16, '무대': 16, '게임': 16, '개인': 16, '로드': 16, '모하': 16, '메드': 16, '주전': 15, '후반전': 15, '해당': 15, '프리미어': 15, '앞': 15, '시작': 15, '춘천': 15, '전망': 15, '성신여대': 15, '디': 15, '기대': 15, '공': 15, '로부터': 15, '한솥': 15, '밥': 15, '리버풀': 15, '스타': 15, '대승': 15, '번호': 15, '역전': 15, '출발': 14, '상황': 14, '앞서': 14, '디애슬래틱': 14, '마수': 14, '걸이': 14, '속': 14, '예정': 14, '영상': 14, '어의': 14, '상의': 13, '가동': 13, '맞닥뜨렸다': 13, '최': 13, '톱': 13, '를': 13, '올해': 13, '대한민국': 13, '음료': 13, '입': 13, '언급': 13, '에릭': 13, '나선': 12, '충돌': 12, '칭찬': 12, '인터뷰': 12, '키': 12, '스포': 12, '티비': 12, '세리에': 12, '국내': 12, '브랜드': 12, '투입': 12, '한편': 12, '포착': 12, '출장': 12, '소식': 12, '이탈리아': 12, '주목': 12, '안토니오': 12, '트위터': 12, '월드컵': 12, '출격': 12, '미드필더': 12, '채널': 12, '천적': 12, '승점': 12, '데이비스': 12, '발탁': 12, '징계': 11, '서로': 11, '서비스': 11, '골대': 11, '머리': 11, '대표': 11, '플레이': 11, '제공': 11, '단짝': 11, '만': 11, '동안': 11, '표': 11, '추가': 11, '볼': 11, '자리': 11, '프로': 11, '틴': 11, '사우스햄튼': 11, '시상': 11, '합류': 11, '진': 11, '속옷': 11, '앰버': 11, '브': 11, '히샤를리송': 11, '시절': 10, '관련': 10, '달': 10, '메일': 10, '모독': 10, '어시스트': 10, '골문': 10, '인지': 10, '중계': 10, '경찰': 10, '착수': 10, '데': 10, '유럽': 10, '호흡': 10, '크로스': 10, '명의': 10, '라인업': 10, '전방': 10, '이제': 10, '존재': 10, '예상': 10, '질문': 10, '모델': 10, '세세뇽': 10, '광고': 10, '훈련': 9, '리지': 9, '골로': 9, '토트넘홋스퍼': 9, '처벌': 9, '항의': 9, '실제': 9, '장면': 9,  ...

# %% [markdown]
# ### 워드 클라우드
# - 한글이 지원되는 폰트를 구해야한다(나눔폰트 등...)
# - 폰트 파일을 다음 경로에 복사해준다.
# - C:\Users\Kullot\anaconda3\Lib\site-packages\pytagcloud\fonts
# - fonts 폴더에 잇는 fonts.json파일을 메모장으로 열어준다.
# - fonts.json 파일에 다음과 같이 넣어준다.</br>
#    {
#         "name": "Korean"    (아무이름)
#         "ttf": "NANUMPEN.TTF"    (폰트파일이름)
#         "web": "http://fonts.googleapis.com/css?family=Nobile"
#     },

# %%
# 가장 빈도수가 많은 단어 100개를 선정한다.
ranked_title_tags = title_count.most_common(100)
ranked_description_tags = description_count.most_common(100)

# %%
# 워드 클라우드를 위한 단어사전을 만든다.
title_tag_list = pytagcloud.make_tags(ranked_title_tags)
description_tag_list = pytagcloud.make_tags(ranked_description_tags)

# %%
# title에 대한 워드 클라우드
pytagcloud.create_tag_image(title_tag_list, './son_title_word.jpg',
                           size=(600, 300), fontname='Nanumpen', 
                            rectangular=False)

# %%
Image(filename='./son_title_word.jpg')

# %%
# description 에 대한 워드 클라우드
pytagcloud.create_tag_image(description_tag_list, 
                            './son_description_word.jpg',
                           size=(600, 300), fontname='Nanumpen', 
                            rectangular=False)

# %%
Image(filename='./son_description_word.jpg')
