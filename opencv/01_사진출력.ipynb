# %%
# 라이브러리 설치
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\pusan\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\pusan\anaconda3\lib\site-packages (from opencv-python) (1.21.5)

# %%
import cv2

# %%
# 이미지를 읽어온다.
src = cv2.imread('./opencv_data/image/yolo_01.jpg')
# 이미지를 불러올 때 데이터의 사이즈를 줄여서 가져온다.
# IMREAD_REDUCED_COLOR_숫자 : 1/숫자 사이즈로 줄여서 가져온다.
src2 = cv2.imread('./opencv_data/image/yolo_01.jpg', cv2.IMREAD_REDUCED_COLOR_2)

# %%
import matplotlib.pyplot as plt
plt.imshow(src)
plt.show()

# %%
# 절대 크기 : 원하는 크기로 이미지 사이즈를 변경할 수 있다.
src3 = cv2.resize(src, dsize=(640, 640))

# 상태 크기 : 비율을 지정하여 이미지 사이즈를 변경할 수 있다.
# fx : 가로 크기 비율 (0~1)
# fy : 세로 크기 비율 (0~1)
src4 = cv2.resize(src, dsize=(0, 0,), fx=0.3, fy=0.7)

# %%
# 이미지를 그린다.
# 첫번째 : 이미지가 나타날 창의 타이틀
# 두번째 : ndarray 형태로 되어 있는 이미지 데이터
cv2.imshow('src', src)
cv2.imshow('src2', src2)
cv2.imshow('src3', src3)
cv2.imshow('src4', src4)
# 이미지가 나타나게 하기 위해 키 입력 대기 함수를 통해 일시 정지 한다.
cv2.waitKey()
# 떠있는 모든 창을 닫는다.
cv2.destroyAllWindows()
