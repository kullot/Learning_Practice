# %%
import bs4
import requests
import pandas as pd
import numpy as np
import time
import json
import os
from IPython.display import clear_output

# %%
# 요청 함수
def getSource(site, start) :
    # 해더 정보 셋팅
    header_info = {
        'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36',
        'X-Naver-Client-Id' : 'opLaOk6efaoqdcpG3V8j',
        'X-Naver-Client-Secret' : 'nvzTR4HuHt',
    }
    
    # 파라미터 데이터
    param_info = {
        'query' : '코로나',
        'display' : 100,
        'start' : start,
        'sort' : 'sim',
    }
    # 요청한다.
    response = requests.get(site, headers=header_info, params=param_info)
    return response.text

# %%
# 한 페이지의 데이터를 가져오는 함수
def getData(source) :
    # 넘어온 데이터를 이용해 json을 분석한다.
    # 딕셔너리와 리스트 형태로 생성된다.
    root = json.loads(source)
    # print(root)
    
    data_dict = {
        'title' : [],
        'link' : [],
        'description' : [],
        'bloggername' : [],
        'bloggerlink' : [],
        'postdate' : [],
    }
    
    
    # items의 수만큼 반복한다.
    for item in root['items'] :
        data1 = item['title']
        data1 = removeChar(data1)
        
        data2 = item['link']
        
        data3 = item['description']
        data3 = removeChar(data3)
        
        data4 = item['bloggername']
        data5 = item['bloggerlink']
        data6 = item['postdate']
        
        # print(data1)
        # print(data2)
        # print(data3)
        # print(data4)
        # print(data5)
        # print(data6)
        # print('-----------------------------')
        
        data_dict['title'].append(data1)
        data_dict['link'].append(data2)
        data_dict['description'].append(data3)
        data_dict['bloggername'].append(data4)
        data_dict['bloggerlink'].append(data5)
        data_dict['postdate'].append(data6)
        
    df1 = pd.DataFrame(data_dict)
    if os.path.exists('./네이버 블로그 api_json.csv') == False :
        df1.to_csv('./네이버 블로그 api_json.csv', encoding='utf-8-sig', index=False)
    else :
        df1.to_csv('./네이버 블로그 api_json.csv', encoding='utf-8-sig', index=False, header=None, mode='a')

# %%
# 문자열 내에서 웹 특수문자를 제거하는 함수
# 다른 것들이 더 있으면 같은 방식으로 작성해주세요
def removeChar(text) :
    # if pd.notna(text) :
    if pd.isna(text) == True :
        return text
    text = text.replace('<b>', '')
    text = text.replace('</b>', '')
    text = text.replace('&quot;', '"')
    text = text.replace('&lt;', '<')
    text = text.replace('&gt;', '>')
    text = text.replace('&apos;', "'")
    return text

# %%
# 전달된 태그로 부터 문자열 데이터를 추출해 반환하는 함수
def getText(tag):
    # 태그가 없다면
    if tag == None :
        return np.nan
    # 문자열을 가져온다.
    data = tag.text.strip()
    # 길이가 0 이라면...
    if len(data) == 0 :
        return np.nan
    return data

# %%
site = 'https://openapi.naver.com/v1/search/blog.json'

start = 1
# 네이버 오픈 api 에서 start는 1000이 최대므로...
while start < 1000 :
    time.sleep(1)
    clear_output(wait=True)
    
    print(f'{start} 수집중')
    
    # 요청한다.
    source = getSource(site, start)
    # print(source)
    
    # 한 페이지의 데이터를 가져온다.
    getData(source)
    
    # start를 100 증가시킨다.
    start = start + 100
print('수집완료')
# Out:
# 901 수집중
# 슬기로운 대학생활 -코로나 예방편-
# https://blog.naver.com/jvu_mngr?Redirect=Log&logNo=222831401420
# 오늘의 슬기로운 대학생활은 코로나 예방편으로 준비했습니다! 다시 재유행을 하고 있는 코로나예방을 미리 알고 예방하는 건강한 비전인이 되보자구요~! 먼저 코로나는 2019년 12월 중국 후베이성 우한시에서...
# 전주비전대학교
# https://blog.naver.com/jvu_mngr
# 20220727
# -----------------------------
# 안전한 여름휴가를 위한 <코로나19 방역수칙>
# https://blog.naver.com/cityansan?Redirect=Log&logNo=222833736132
# 안전한 여름휴가를 위한 코로나19 방역수칙 1 다중이용시설 방문 시 개인위생 철저 2 밀폐·밀집·밀접한 장소에서 마스크 올바르게 착용 3 코로나19 증상 발현 시, 신속히 진료 받고 타인 접촉 최소화 4 고령...
# 안산시 공식 블로그
# https://blog.naver.com/cityansan
# 20220729
# -----------------------------
# [20220727] 일본 코로나가 심각하긴 함...
# https://blog.naver.com/dbswjddkzm?Redirect=Log&logNo=222832823089
# 우리나라는 한때 하루 확진자 수 60만 명을 기록하던 적이 있어서 그 이후로는 '코로나? 좀 많이 아프고 강한 독감에 가까운 병' 이라는 분위기가 형성된 것 같은데 일본은 코로나에 걸리면 왜? 어디서? 누구랑...
# ▒▒▒레비비의블로그▒▒▒
# https://blog.naver.com/dbswjddkzm
# 20220728
# -----------------------------
# 코로나 재감염 격리, 증상, 기준 등 총정리(22년 8월 기준)
# https://blog.naver.com/yeonkyung25?Redirect=Log&logNo=222843178721
# 오늘은 '코로나 재감염'에 대해서 알아볼게요. 코로나 재감염 시 격리를 해야 하는지, 코로나 재감염 증상은 어떤 것들이 있는지, 재감염의 기준은 무엇인지 등등 정리해 보았습니다. *질병관리청 지침을...
# 하다해경의 꿈밭
# https://blog.naver.com/yeonkyung25
# 20220808
# -----------------------------
# 인천공항 입국절차, 미국 입국 코로나 검사 폐지
# https://blog.naver.com/tnwlsdl702?Redirect=Log&logNo=222770249466
# 인천공항 입국절차, 미국 입국 코로나 검사 폐지 오늘 미국에서 들려온 가장 반가운 소식이 하나 있는데요 바로 미국 입국 시 필요했던 코로나 검사가 전격적으로 폐지되었다는 소식이에요! 괌, 사이판을...
# 책상에서 즐기는여행이야기
# https://blog.naver.com/tnwlsdl702
# 20220612
# -----------------------------
# 코로나 이후 ‘자살생각률’ 3배 늘어…“정신건강 서비스...
# https://blog.naver.com/mirae_saram?Redirect=Log&logNo=222845600461
# 보건복지부가 10일 발표한 ‘2022년 2분기 코로나19 국민 정신건강 실태조사’ 결과에 따르면... ‘자살생각률’은 코로나 이전보다 3배 가까이 증가한 것으로 나타났습니다. 이번 조사는 지난 4월 18일...
# 대한민국 인사혁신처
# https://blog.naver.com/mirae_saram
# 20220811
# -----------------------------
# 코로나 소상공인 손실보상 신청완료
# https://blog.naver.com/ssabj?Redirect=Log&logNo=222835989542
# #손실보상 #소상공인손실보상 #손실보상신청 #소상공인손실보상신청 코로나 방역 때문에 영업제한을... 코로나 바이러스 때문에 장사가 어려워진 시기에 소상공인 사장님들 모두 힘내시고 파이팅 하시고...
# 대안쑥뜸
# https://blog.naver.com/ssabj
# 20220801
# -----------------------------
# 코로나를 이겨내고 부활! 영화관 이벤트 비교
# https://blog.naver.com/toiko2?Redirect=Log&logNo=222832628937
# 마침 코로나 거리두기 단계가 완화되면서 이전에는 빛을 보지 못했던 다양한 분야의 산업들이 서서히... 이렇듯 다양한 이벤트를 진행하며 코로나를 이겨내고 부활하고 있는 영화산업!  코로나가 시작된 이후...
# 중앙대학교 광고홍보학과 웹진
# https://blog.naver.com/toiko2
# 20220728
# -----------------------------
# 코로나19 4차접종 대상자는?
# https://blog.naver.com/doctorbae75?Redirect=Log&logNo=222826788526
# [코로나19 백신 4차 접종 대상자는?] 코로나19가 잠잠해지면서 야외활동시 마스크도 벗고 모임도 활성화되면서 좋았는데, 점차 코로나가 재유행할 조짐이 보이면서 코로나 백신 접종에 대해...
# 서울배내과
# https://blog.naver.com/doctorbae75
# 20220724
# -----------------------------
# 코로나19와 정리
# https://blog.naver.com/genius1146?Redirect=Log&logNo=222848118081
# 중국에 코로나19때문에 봉쇄를 한다는 뉴스를 보면서 식사를 했던 기억이 있다. 우리까지 많은 영향을 미치겠느냐는 안일한 생각이 그때까지는 사로 잡혀 있었다. 그로부터 2년이 지난 지금은 실생활에 코로나19...
# Project To Be 아.친.딸.
# https://blog.naver.com/genius1146
# 20220814
# -----------------------------
# [베트남 '22] 다낭 공항 코로나 신속항원검사 무료라 좋다.
# https://blog.naver.com/haming00?Redirect=Log&logNo=222833132919
# ㅠ_ㅠ 입국 전 코로나 검사: 3가지 방법 한국에 입국하는 모든 해외 입국자에 대해서는 내국인도 코로나 음성확인서를 제출해야 하므로 베트남에 가기 전부터 검사를 어디에서 해야 하나 생각을 많이...
# 느리게 걷기 :)
# https://blog.naver.com/haming00
# 20220729
# -----------------------------
# 코로나19 팬데믹 이후 청년관광 소도시편 [제6회 관광지식...
# https://blog.naver.com/kcti0?Redirect=Log&logNo=222850709449
# 다섯번째 수상작, 우수상 을 수상한 '코로나19 팬데믹 이후 청년관광 소도시편'(노정민 외 3인, 우리가... 카드뉴스인데요~ 코로나19 이후 주목받게 될 소도시관광과 청년층에 대해 공부해보는 시간을...
# 관광을 담다, 내일을 보다.
# https://blog.naver.com/kcti0
# 20220817
# -----------------------------
# 코로나 유급휴가 지원금 기준이 변경됨!
# https://blog.naver.com/kyungslife?Redirect=Log&logNo=222829627233
# 코로나가 잠잠하더니 직장동료 한분이 코로나 확진 판정을 받음. 하여 혹시 그 사이 코로나 지원금 변동이 있을까 접속 해 보았음. 헉!! 이런! 7월11일부터 코로나 유급 휴가 지원금 신청이 개편 되었다고 함....
# 전지적 작가시점, 달려라 엄마&apos;s 세상의 모든 리뷰
# https://blog.naver.com/kyungslife
# 20220726
# -----------------------------
# 천식환자 코로나 확진
# https://blog.naver.com/lje1541?Redirect=Log&logNo=222815450558
# 8도 새벽에도 아파서 잠을 계속 깼다 이정도면 양성이 나오겠구나 생각하고 "코로나 확진 수액" 검색... 그렇게 안내리던 열도 내리고 몸이 괜찮아지는 것 같았다 근데 이번 코로나 뭐냐 아프다 괜찮다 아프다...
# 반려인의 천식일기
# https://blog.naver.com/lje1541
# 20220717
# -----------------------------
# 코로나 병상 일지
# https://blog.naver.com/wlsdl1000?Redirect=Log&logNo=222831773179
# 코로나라고 생각도 못 했던 터라 격리하는 동안 집에 먹을 게 없어서 마스크 쓰고 잽싸게 장 보러 다녀옴(코로나에 좋다고 하는 감기약, 생강차 등등 잔뜩 사 옴) 3일차 7월 10일 일요일 잔잔하게 기침 시작...
# LOVE THE LIFE YOU LIVE
# https://blog.naver.com/wlsdl1000
# 20220727
# -----------------------------
# 코로나일까?(+근육통)
# https://blog.naver.com/roadnottak?Redirect=Log&logNo=222835384247
# 때문에 코로나에 걸리면 집사를 노예로 강등시키겠어!" 입버릇처럼 말했지만, 쫄지도 않고 의미도... 코로나를 이만큼만 앓고 지나가는 큰 행운과 항공권 가격이 높아져 버린 아주 깨알 같은 불운을 같은...
# 덤으로 산다
# https://blog.naver.com/roadnottak
# 20220731
# -----------------------------
# 위드코로나 시대 서울시 코로나19 평가와 건강도시 정책방향
# https://blog.naver.com/seoulinst?Redirect=Log&logNo=222842912415
# 유럽건강도시들, 코로나19에 ‘속수무책’…감염병 대응력 강화 요구 서울시는 2004년 WHO 건강도시에... 하지만, 2020년 코로나19가 전 세계적으로 급속하게 퍼져나가면서 대도시의 취약성이 드러나게...
# 서울연구원 공식블로그 The Seoul Institute
# https://blog.naver.com/seoulinst
# 20220808
# -----------------------------
# [9번째] 코로나 확진 / 바다가 들린다 / 사거리 &amp; 네거리
# https://blog.naver.com/hongju3498?Redirect=Log&logNo=222846130232
# 코로나 확진되고 나서 나가질 못하고 있다 8월 8일 오후에 갑자기 머리가 아팠다 아플 이유가 없는데 아파서 의심됐다 그 날은 그냥 집에서 보내보기로 했다 8월 9일 아침에 일어났더니 머리 아픈 것 뿐만 아니라...
# 심심풀이
# https://blog.naver.com/hongju3498
# 20220811
# -----------------------------
# 코로나 병원 신속항원검사 양성 결과 나오는 시간 비용 정리...
# https://blog.naver.com/meyou27?Redirect=Log&logNo=222845385738
# 코로나 검사에는 두가지 방법이 있다. PCR검사, 신속항원검사 한창 코로나가 심했을때 선별진료소에서 받았던건 PC검사였고, 우리가 집에서 하는 자가검사키트는 신속항원검사인데 원리는 동일하나 사용하는...
# 꿈을 향한 모든 순간, 그 기록
# https://blog.naver.com/meyou27
# 20220812
# -----------------------------
# 대전 유성구 소식, 코로나19 생활지원금 신청 온라인으로...
# https://blog.naver.com/yuseonggu?Redirect=Log&logNo=222795921159
# 대전 유성구 소식, 코로나19 생활지원금 신청 온라인으로 간편하게! 코로나19 확진자 수가 날로 날로 줄어들고 있습니다. 이제는 일상으로의 회복이 코앞에 와있다는 사실에 덥고 습한 여름이 다가오지만...
# 유성구 공식 블로그
# https://blog.naver.com/yuseonggu
# 20220701
# -----------------------------
# 코로나로 자가격리중 만들어 먹은 초간단 전복내장죽
# https://blog.naver.com/tessus?Redirect=Log&logNo=222845301918
# 코로나로 자가격리중 만들어 먹은 초간단 #전복내장죽 #죽, #전복내장, #전복내장죽쑤는법... 지났거든요~그런데 코로나로 자가격리중이라 먹는 것에 신경이 쓰이더라구요술람미야 집에 있으면 되지만 남편을...
# 술람미의 세상엿보기
# https://blog.naver.com/tessus
# 20220811
# -----------------------------
# 코로나재유행 선제적 대응, 임시선별검사소가 확대운영됩니다.
# https://blog.naver.com/nscity?Redirect=Log&logNo=222836263249
# 코로나19 재유행에 따른 선제적 대응책의 일환으로 28일부터 시민과 외국인을 대상으로 코로나19검사를 무료로 실시합니다. 현재 전국적으로 코로나19 확진자 수가 급격하게 증가하고 있는 것은 물론...
# 논산시 공식 블로그
# https://blog.naver.com/nscity
# 20220801
# -----------------------------
# 올 것이 왔다 코로나 확진 일일차
# https://blog.naver.com/yhj5292?Redirect=Log&logNo=222836931116
# 코로나 확진 일일차 잘 버틴다 했는데... 식도염 때문에 계속 잘 못먹고 잘 못자고 그래서 였을까...!?... 코로나 얘긴 없었다. 증상 다 설명했는데 ㅠ ㅠ... 암튼 수액맞고 귀가...그런데 여전히 더운데 춥고! 에어컨...
# 따쟁이의손그림하우스
# https://blog.naver.com/yhj5292
# 20220801
# -----------------------------
# 블챌 주간일기 8월3주/삼형제육아일기/코로나의 습격
# https://blog.naver.com/cutedud82?Redirect=Log&logNo=222848854167
# 코로나 확산세가 심상치않다했더니 역시 우리집도 피해갈 수 없었다. 지난 금요일 둘째가 열이 나길래 병원에 가서 검사하니 코로나 양성. 토요일 첫째도 열이나서 검사해보니 코로나 양성이다. 첫째는 지난...
# 소소한 일상
# https://blog.naver.com/cutedud82
# 20220815
# -----------------------------
# 코로나 확진자 생활지원금 신청 신청서 자가격리
# https://blog.naver.com/dongi0508?Redirect=Log&logNo=222673843823
# 코로나 확진자 생활지원금 신청 신청서 자가격리 드디어! 우리 가정에도 확진자가 한 명 발생했다!... 그러는 와중에 코로나 생활지원금 이거 예산이 부족한가부다... 금액이 훨씬 더 줄어들었다는. 아무래도...
# Der Sinn des Lebens
# https://blog.naver.com/dongi0508
# 20220316
# -----------------------------
# 코로나19 감염확대！
# https://blog.naver.com/changsoo_kim?Redirect=Log&logNo=222834656577
# 코로나19 감염확대！ 2022年07月29日 겐다이헬쓰캐어 코로나19의 감염확대는 여전히 가라앉을 기미가 없고, 마스크의 착용, 손씻기, 환기, 3밀(三密)의 회피 등 사람들은 계속해서 여러 가지 방법을 쓰고 있다。...
# changsoo_kim님의 블로그
# https://blog.naver.com/changsoo_kim
# 20220730
# -----------------------------
# 코로나 회복. 자가격리 끝
# https://blog.naver.com/sjftlddbejq?Redirect=Log&logNo=222839178611
# 근데 송곳니 이앓이가 겹쳐서 왔다 어금니 하나가 잇몸을 뚫고 나온 줄 알았는데 알고보니 지금 뚫은 듯 아래 송곳니도 느껴진다 친정엄마도 참고로 코로나 걸렸었음 오늘은 남편은 집에 있고 나랑 아기만...
# 캐나다 간호사 일상/직장 Diary
# https://blog.naver.com/sjftlddbejq
# 20220804
# -----------------------------
# 코로나 생활지원금 지원 대상 축소 (중위소득 기준 및 건보료)
# https://blog.naver.com/meaning87?Redirect=Log&logNo=222806981387
# 코로나 생활지원금 지원 축소 기존 : 모든 가구 지급 (1인 10만원, 그 외 15만원) 변경 : 중위소득 100... 지급되던 코로나 생활지원금을 중위소득 100% 이하인 가구에게만 지급하도록 제도가 변경됐습니다....
# 은퇴연구소
# https://blog.naver.com/meaning87
# 20220711
# -----------------------------
# 코로나 기록
# https://blog.naver.com/lovinblu?Redirect=Log&logNo=222837845141
# 코로나 확진 4일째 ㅇ딸은 잔기침 말고는 증상이없다. 그치만 잘때마다 마른기침을 해서 안쓰럽다. 목에... 아들은 코로나 확진 3일째.. 그제 밤에 해열제가 듣지 않았고 체온이 떨어져봤자 38도대였다....
# 푸른 새벽의 피아노
# https://blog.naver.com/lovinblu
# 20220802
# -----------------------------
# 책의 숲속에 파묻혀 지낸 코로나 격리 여름휴가
# https://blog.naver.com/de_mai?Redirect=Log&logNo=222848555469
# 우선 코로나에 걸리고 나서 처음에는 열이 무진장 났다. 그런데 다른 증상이 아무것도 없었기 때문에 설마하는 생각에 자가진단키트를 했지만 코로나일 거라고는 생각을 못했던 것 같다. 하지만 나는 의심이...
# 오월다방
# https://blog.naver.com/de_mai
# 20220815
# -----------------------------
# 코로나 4일~5일차(확진자 대면 진료)
# https://blog.naver.com/love1234ming?Redirect=Log&logNo=222844631054
# 되지 않았으면 좋겠습니다 바뀐 약들을 받아 집에 왔다. 아직 불편한 증상들이 있지만 첫날에 비하면 상당히 나아진 편이라 생각한다. 열심히 밥과 약을 잘 먹어서 남은 증상들도 다 없애버려야지. 사라져라 코로나!
# 시작은i로부터
# https://blog.naver.com/love1234ming
# 20220810
# -----------------------------
# 코로나 세대 아이들의 아픔, 자소서컨설팅 충격
# https://blog.naver.com/monoblue01?Redirect=Log&logNo=222831719414
# 지금 고3 학생은 2020년에 고등학교 입학을 했는데 (코로나가 2019년 12월 중국에서 뉴스 나오고 우리 나라는 2020년 1월에 뉴스 나온것으로 기억..) 세상에나!! 고등학교 입학한 첫 해부터 시작된 코로나로 학교...
# 루윙코치 교육정보&육아일상
# https://blog.naver.com/monoblue01
# 20220727
# -----------------------------
# 코로나 4차 접종 예약 방법은?
# https://blog.naver.com/bora912?Redirect=Log&logNo=222837840157
# 코로나 재확산세로 인해 확진자가 점차 늘어나고 있는 요즘이에요. 7개월된 아기와 유치원생이 있는 저희집은 늘 뉴스를 보며 긴장하게 되는데요. 코로나 확진자가 10만여명을 육박했다고 하니...
# 나의 경제적 해방일지
# https://blog.naver.com/bora912
# 20220802
# -----------------------------
# 코로나 40일만에 최다 확진, 최근 7일간 최다발생국
# https://ystazo.tistory.com/1738
# 4월의 코로나 확진 대폭발도 이제 3개월이 지나고 있으니 항체 효능이 떨어지는건지. 그래도 아직... 신규 하위 변이도 꾸준히 나오고 있는 코로나 바이러스. 정말 완전한 종식이 언제일런지요. 화이자, 모더나...
# TASTORY : 타스토리!
# https://ystazo.tistory.com/
# 20220705
# -----------------------------
# 코로나가 우리집에도 상륙한 날
# https://blog.naver.com/dolsun99?Redirect=Log&logNo=222834774844
# 코로나가 기승을 부리던 2년 넘도록 잘 버텨왔던 우리집에도 반갑지 않은 코로나가 상륙했다. 남편이 어제 퇴근해 오면서 목이 칼칼해서 코로나 검사를 받고 왔다 했다. 같이 근무하는 직원이 어제 코로나...
# 삶이 내게 말을 걸어올때
# https://blog.naver.com/dolsun99
# 20220730
# -----------------------------
# 코로나 관련 입국 서류 전면 폐지! 프랑스 출입국 최신 소식
# https://blog.naver.com/francois09?Redirect=Log&logNo=222837654511
# 이상 코로나 관련 어떤 서류도 준비할 필요 없이 가볍게 여행을 떠날 수 있다는 소식입니다❤ ⓒHanbi LEE 프랑스가 코로나19로 인해 "보건 비상사태"를 선언한 이후, 여행객들은 프랑스 입국 시 백신...
# 프랑스 여행 이야기
# https://blog.naver.com/francois09
# 20220802
# -----------------------------
# 켄타우로스(BA.2.75) 코로나19 변이바이러스
# https://blog.naver.com/clamille1004?Redirect=Log&logNo=222829064567
# 한동안 저도 잠시 코로나에대해 좀 풀어지기도 했었네요.여름휴가를 준비한던중 너무 심각하게 다시 확진자가 늘고 있어서관심없다 다시금 코로나 변이 바이러스에 대해 알아보다가 포스팅해서...
# maybee another day
# https://blog.naver.com/clamille1004
# 20220726
# -----------------------------
# 코로나19 이후 전 세계 학습 빈곤율
# https://blog.naver.com/unicefgarden?Redirect=Log&logNo=222824421860
# 코로나19로 인한 정상적인 학교 교육의 부재로 학습 불평등이 심화되고 있습니다. 수많은 학교가... 그러나 코로나19 이후, 학습 빈곤 문제는 더욱더 심각합니다. 일부 국가는 몇 주부터 길게는 2년...
# 유니세프 WeAction
# https://blog.naver.com/unicefgarden
# 20220722
# -----------------------------
# 코로나 시대를 맞아 변화하는 근무형태
# https://blog.naver.com/liber10?Redirect=Log&logNo=222832940348
# 코로나 시대를 맞아 변화하는 근무 형태 -Jim Cahill, Nathan Pettus 올랜도에서 열린 2022년 ARC 산업... 에머슨 제어 시스템과 기술을 이용해 제조한 코로나 19 백신을 예로 들면, 이 프레임워크는 날이...
# 공정 자동화를 위한 최고의 기업 | 한국 에머슨
# https://blog.naver.com/liber10
# 20220801
# -----------------------------
# 해외여행 코로나 음성확인서 PCR검사 무료? 신속항원검사로 해결
# https://blog.naver.com/lkdrkdrl?Redirect=Log&logNo=222836889466
# 전후 코로나검사를 하는 국가는 OECD 38개국중 한국 뿐입니다 한국행 비행기를 타려면 출발 일전 48시간... 해외여행 코로나 음성확인서 발급 하는 방법에 대해 알려드렸습니다 보건소 PCR검사는 무료 대상이...
# NEWTURN
# https://blog.naver.com/lkdrkdrl
# 20220801
# -----------------------------
# 미 정보 당국, 코로나 '우한 유출설' 조사
# https://blog.naver.com/philo515?Redirect=Log&logNo=222836971868
# 미국 정보 당국이 신종 코로나바이러스의 기원에 관한 독자 조사를 곧 마치고 조 바이든 대통령에게 보고서를 제출할 예정으로 알려졌다. 관심을 끄는 것은 과연 신종 코로나가 중국 우한의 바이러스...
# 하얀구름 (philo515)
# https://blog.naver.com/philo515
# 20220802
# -----------------------------
# 코로나 해프닝
# https://blog.naver.com/rizet?Redirect=Log&logNo=222835571797
# 코로나 양성이군요. 이런 일이 우리 집에도 일어나는구나. 그것도 70이 훌쩍 넘은 우리 엄마가 코로나에 걸렸다. 며칠 전 쓰레기를 정리하다가 손을 베서 오열하셨던 우리 어머니. 그날 저녁에 몸이 좀 아프시다고...
# Tash&apos;s Story
# https://blog.naver.com/rizet
# 20220731
# -----------------------------
# 어린이 코로나 증상 [ 고열 복통 ], 사망 위험 미리 확인하세요!
# https://blog.naver.com/coffeensalad?Redirect=Log&logNo=222841617040
# 7월 코로나19 인한 어린이 사망자가 경기도 2명, 세종 1명, 광주 1명 총 4명이 발생하는 안타까운 사건이... Content 소아 코로나 증상 소아 코로나 증상별 대응요령 소아 코로나 위험 증상 그 밖의 코로나19 관련...
# 자영업자 김사장의 사회,경제 이야기
# https://blog.naver.com/coffeensalad
# 20220807
# -----------------------------
# 이번주는  코로나 ㅠㅠ  너무 아파요...
# https://blog.naver.com/ryang1216?Redirect=Log&logNo=222848309724
# #주간일기 #블챌 #코로나 #응급실 안녕하세요 ~ 이번주는 ㅠㅠ 진짜 코로나 땜에 너무 힘드네요 ㅠ 남편네 회사 분들이 하나 둘 감염되기 시작하더니 남편이랑 같이 밥 먹은 사람이 코로나 확진 남편은 목요일...
# 레이나&apos;s 일상♪
# https://blog.naver.com/ryang1216
# 20220814
# -----------------------------
# 코로나 확진, 그리고 깨달은 몇 가지
# https://blog.naver.com/yoonda_?Redirect=Log&logNo=222841622129
# 아침 식사 후 혹시나 하는 마음에 집에서 코로나 자가 진단키트로 검사를 해보았다. 두 줄이 똭!... 8/3 (수) 코로나 확진 아침 눈뜨자마자 체온 37.4 증상은 열, 두통, 인후통. 목이 잠기고 목소리 크게 내는데...
# Yoonda
# https://blog.naver.com/yoonda_
# 20220807
# -----------------------------
# 코로나 자가진단키트 대량구매 찾고계세요?!
# https://blog.naver.com/prosean?Redirect=Log&logNo=222836008985
# 코로나 더블링 현상... (하루 확진자 2배씩 증가) 코로나 재유행 징조 거리두기 강화 재검토... 다시 코로나가 재유행 조짐을 보이면서 우리 걱정도 이만저만이 아닌데요... 이제 좀 그만했으면...
# 낙원으로 가는 티켓
# https://blog.naver.com/prosean
# 20220801
# -----------------------------
# 이우코로나사태 500명, 이우 셧아웃(22.8.11)
# https://blog.naver.com/easychina?Redirect=Log&logNo=222846130356
# 이우코로나사태 9일만에 500명 넘었습니다. 이우시 코로나 양성감염자 24명 신규 증가 통보 浙中都市圈 2022-08-11 09:54 发表于浙江 8월 10일 21시 ~8월 11일 9시까지 이우시에서 24명의 양성자가 발견되어 재검사를...
# 중국음악세상
# https://blog.naver.com/easychina
# 20220811
# -----------------------------
# 한국 입국 준비! 총정리 : Q코드, 코로나 검사 from 캐나다
# https://blog.naver.com/domoto777?Redirect=Log&logNo=222840820250
# 코로나 음성 결과지 2. Q코드 작성 1. 코로나 음성 결과 코로나 음성 결과지는 꼭 지참해야합니다. 체크인을 할 때 부터 확인하더라구요. 이제는 PCR검사 뿐만 아니라 신속항원검사(rapid antigen test)도...
# 고모늘보 이야기
# https://blog.naver.com/domoto777
# 20220806
# -----------------------------
# 50대·18세이상 기저질환자 등 코로나 4차접종 권고
# https://blog.naver.com/eunyo20?Redirect=Log&logNo=222809796195
# 코로나19 예방접종 대응추진단은 재유행이 우려되는 상황에서 고위험군의 중증사망 예방을 위해... 4차 접종 효과 추진단은 국내 코로나19 4차접종 효과 분석 결과, 3차접종군 대비 4차접종군의 감염...
# 바이오가 세계를 바꾼다
# https://blog.naver.com/eunyo20
# 20220713
# -----------------------------
# 주간일기 (내가 코로나 확진자라고?)
# https://blog.naver.com/siraasony?Redirect=Log&logNo=222813651595
# 이제야 걸리고 말아버린 코로나. 엥? 에에엥? 요새 증상은 고열과 오한이라고 합니다... 금요일에 목이... 거의 코로나라고 하더라구요...ㅎ.. 양성 죽어도 음성클럽에서 이제야 탈출했구요 업글인간이...
# 소니의 솔직 담백한 블로그
# https://blog.naver.com/siraasony
# 20220716
# -----------------------------
# 코로나 확진 후유증 구로 아나파한방병원 입원 치료 후기 ( 증상...
# https://blog.naver.com/mgamp?Redirect=Log&logNo=222821010650
# 코로나 확진 후유증 구로 아나파한방병원 입원 치료 후기 증상 : 어지러움, 가래, 피로, 두통 안녕하세요! 최근 코로나 확진 되는 분들이 엄청 늘고 있잖아요. 저도 최근에 걸렸었거든요. 그 때 증상이 심해서...
# i like hm
# https://blog.naver.com/mgamp
# 20220720
# -----------------------------
# 위드 코로나 직장 생활 보고서
# https://blog.hyosung.com/5599
# 코로나19로 인해 변화한 근무 환경과 더불어 직장인의 인식 변화를 들여다봤습니다. 글. 김희선 - 달라져서 오히려 좋아!? 코로나19 장기화로 직장인 회식 문화에 많은 변화가 있었다. 방역 규제가 강화되면서...
# 마이프렌드 효성 블로그
# https://blog.hyosung.com/
# 20220621
# -----------------------------
# 3.13~17 코로나확진ㅡ 잘극복했어♡
# https://blog.naver.com/drjylove?Redirect=Log&logNo=222811074826
# 아빠회사서 코로나 검사하고왔어요 그런데 오후가 지나서 신이안 40도.. 해열제 싫데고... 그래도 코로나 같다고 하니 먹더라구요 심심한 해안이 잘 잔 이안이 3시간 푹자더니 열떨어지고 극복^^ 아팠으니까...
# 반짝반짝 이안이네
# https://blog.naver.com/drjylove
# 20220714
# -----------------------------
# 코로나검사
# https://blog.naver.com/haend9328?Redirect=Log&logNo=222827160250
# 코로나 언제 끝나려나? 영원히 안 끝나려나? 날도 더운데 마스크 너무 싫다 불과 몇년 전 코로나가 시작되기 전 얼마나 자유롭고 행복했던 시간이었는지 잃어버리고나서야 그 시간이 소중했다는것을 느낀다...
# Always Happy!!!
# https://blog.naver.com/haend9328
# 20220724
# -----------------------------
# 코로나 격리 마지막날, 앞으로는 어떤 부동산이 좋은...
# https://blog.naver.com/flyingowlad?Redirect=Log&logNo=222843590950
# 지겨웠던 코로나 격리 일주일.... 드디어 오늘까지만 참으면 저의 격리가 해제됩니다 딸이 확진되고 그... 딸은 코로나 덕분에 학원에도 안가고 하루종일 집에서 뒹굴거리니 너무 좋다하고.....직장을 다니는...
# 부엉이날다 :: 아름다운 그대
# https://blog.naver.com/flyingowlad
# 20220809
# -----------------------------
# 2022년 8월 12일 다이어리 - 중국 하루 신규 코로나 확진자...
# https://blog.naver.com/j13month?Redirect=Log&logNo=222846286684
# 오늘 아침 중국 발행 신문을 읽다 보니 눈에 띄는게 중국 현재 하루 신규 코로나 확진자 숫자가 폭발적 증가 하고 있는 점 솔직히 중국이 코로나 신규 확진자가 800명대 까지 육박 하다가 300명대 까지 내려가서...
# 바람의 내음.........
# https://blog.naver.com/j13month
# 20220812
# -----------------------------
# ‘코로나19 재유행에 대비한다’, 의료기술직 공무원
# https://blog.naver.com/gosomi3355?Redirect=Log&logNo=222801245688
# 교육의 목표는 코로나19 재유행을 대비하고 차별화된 지역사회 통합건강증진사업 추진을 위함으로 전해졌다. 이번 교육은 코로나19 등 팬데믹 시대 감염병 대응과 관련하여 의료기술직렬 공무원의 역할을...
# 그는 유리눈물을 흘렸어요
# https://blog.naver.com/gosomi3355
# 20220705
# -----------------------------
# 코로나19 관련 응급실 코호트 구역 안내 .  변경
# https://blog.naver.com/orogi78?Redirect=Log&logNo=222842568838
# 코로나19 관련 응급실 코호트 구역 안내 응급실에 내원한 코로나19 확진자 및 감염위험도가 높은 환자를 대상으로 응급실 내·외부에 설치된 코호트 구역에서 진료한 경우 산정 가능한 수가 및 청구방법 등을...
# 병원 개업의 정석
# https://blog.naver.com/orogi78
# 20220808
# -----------------------------
# 코로나 일기
# https://blog.naver.com/cheimh?Redirect=Log&logNo=222835399514
# 결국 걸리고 말았네요~ 코로나 ㅜ 지난 화요일 아침에 큰아이를 독서실에 데려다주는데 엄마~ 잠을 많이... ㅋㅋㅋㅋㅋ 우띠 ㅠ 토욜 아침에 병원 갔더니 돌발성난청이라고~ 코로나로 인해 발생했을 가능성도...
# 악마토끼의 달큰한 유혹~❤
# https://blog.naver.com/cheimh
# 20220731
# -----------------------------
# 주간일기7. 걱정되는 코로나재유행
# https://blog.naver.com/sunmin3283?Redirect=Log&logNo=222825900204
# 이래서 코로나가 재유행이라는 이야기에 외부접촉을 줄이는 일부터 한다. 체험단도 이제 신청 안함 3월에 코로나 한 번 걸렸었는데 폐렴까지 왔었던 지라 혹시 모를 재감염이 걱정되어 조심 중이다 지인도...
# 소소하게, 담백하게 주부의 일상
# https://blog.naver.com/sunmin3283
# 20220723
# -----------------------------
# 광주 코로나 검사 후기 / 북구미래아동병원, 보건소 pcr검사...
# https://blog.naver.com/sb3161sb?Redirect=Log&logNo=222836735898
# #코로나확진자 #코로나 #코로나확진자병원 #코로나대면치료 #코로나수액 #아이병원 #아기코로나 #광주코로나 #코로나비대면치료 #코로나확진자수액 #코로나해열제 #광주북구보건소 #확진자증상 #코로나증상...
# 이서와 함께하는 육아블로그
# https://blog.naver.com/sb3161sb
# 20220801
# -----------------------------
# 신종 코로나바이러스 재확산 예방가능한 노바이러스 공기살균기
# https://blog.naver.com/gatewelly?Redirect=Log&logNo=222840057438
# 다시 재확산된 코로나 바이러스! 무려 10만명이 넘어갈만큼 다시 바이러스로부터 안전하지 않는 시기가 오게 되었는데요, 다들 어떻게 코로나 바이러스를 예방하고 있으신가요? 많은 분들이 운동을 하거나...
# GATEVISION 다이슨 로라스타 이메텍 비쎌 노바이러스
# https://blog.naver.com/gatewelly
# 20220805
# -----------------------------
# 코로나 19랑 멀어지기
# https://blog.naver.com/poohel7979?Redirect=Log&logNo=222847585108
# 코로나 19가 점점 나(가족들)한테서 멀어지고 있다. 남은 건 두통과 어지럼, 그리고 목 안에 제거하기... 점점 식욕이 돌아오지만 양은 안 졸아왔음 좋겠다는 ㅋㅋㅋㅋ 이번주는 정말 코로나 때문에 너무 길었다....
# 다시, 새롭게
# https://blog.naver.com/poohel7979
# 20220813
# -----------------------------
# 타액으로 검사하는 코로나19자가키트
# https://blog.naver.com/cool_ami79?Redirect=Log&logNo=222827672736
# 떨어져서 코로나19가 아닌 듯 하기도 하고 병원에서도 목과 코가 부어서 결국 항생제를 먹고 있습니다. 그런데 . . . 첫째도 감기 기운이???? ㅋ 그래서 결국 학교를 보내지 않고 #코로나검사키트 구입하러...
# 세상을 향한 외침
# https://blog.naver.com/cool_ami79
# 20220725
# -----------------------------
# 코로나땜에 망한 내 여름휴가
# https://blog.naver.com/zhhlove?Redirect=Log&logNo=222826983630
# 하....여름휴가 앞두고 코로나걸려버린 이 빡치는 상황 주간일기때문에 기록한다 7.21 오전에 바로... 혹시나싶어 코로나 검사했을땐 음성 7.22 출근하기 전 어머님이 주신 전문가용 완전 길쭉한걸루다가...
# 장화블로그
# https://blog.naver.com/zhhlove
# 20220724
# -----------------------------
# 내가 코로나라니…
# https://blog.naver.com/happiness309?Redirect=Log&logNo=222830560822
# 7.18일 코로나 확진 받고 멘붕에 빠진 가족들 내가왜??? 아기랑 거의 집에만있었는데??? 그리고 가족 중... 그렇다고 낮잠을 잔것도 아닌데… 찾아보니 코로나 증상중에 불면증도 있었다 하 가지가지하네 진짜...
# # 전지적 쏭지 시점
# https://blog.naver.com/happiness309
# 20220727
# -----------------------------
# 한국 입국 pcr 절차 코로나 검사 해외입국후 하루
# https://blog.naver.com/dongi0508?Redirect=Log&logNo=222827442666
# 한국 입국 pcr 절차 코로나 검사 해외입국후 하루 뉴스를 보니까 국내에서 계속되는 코비드19... 인천공항에서 한국 입국후 pcr 검사 바로 하고 싶은 분들을 위하여 인천국제공항 T1 코로나 19검사 센터 위치를...
# Der Sinn des Lebens
# https://blog.naver.com/dongi0508
# 20220725
# -----------------------------
# 코로나19 백신 4차 접종대상 확대! 50세 이상 및 고위험군...
# https://blog.naver.com/goodnowon?Redirect=Log&logNo=222822319081
# 코로나19 백신은 접종 이후 일정 시일이 경과함에 따라 그 접종 효과 및 자연 면역 효과가 감소하므로 접종 간격에 따른 n차 접종이 이루어지게 됩니다. 뉴스를 통해 코로나 재유행이 예상되고 있는 요즘...
# 노원구청 공식 블로그
# https://blog.naver.com/goodnowon
# 20220721
# -----------------------------
# 프랑스 2022년 8월1일부터 입국시 코로나 검사 안하기로
# https://blog.naver.com/uwilmsme?Redirect=Log&logNo=222839777158
# 해제되고 코로나19 관련 모든 규정이 폐지되었다. 이에 따라 프랑스 본토 및 해외 영토로 여행하는 해외 여행자들은 더이상 백신접종 확인서나 코로나 검사 음성확인서를 제출 하지 않고도 프랑스...
# Gromit&apos;s world
# https://blog.naver.com/uwilmsme
# 20220804
# -----------------------------
# 코로나 확진 판정, 아내와 코로나 양성 판정으로 자가격리 시작
# https://blog.naver.com/synabro68?Redirect=Log&logNo=222833037677
# 오늘 최종적으로 코로나 양성 판정을 받아 저도 코로나 확진자가 되었습니다. ㅜ_ㅜ 어제 아내가 직장인 어린이집에서 월요일에 등원한 아이가 확진자로 판명이 되어 그 아이의 담임이라 밀접 접촉으로 자가진단...
# 또 다른 세상, 또 다른 나
# https://blog.naver.com/synabro68
# 20220728
# -----------------------------
# [주간일기 09] #코로나
# https://blog.naver.com/goodmyway?Redirect=Log&logNo=222828600109
# #코로나 2020년 봄 코로나(covid 19)가 찾아왔다. 2019년 겨울 무렵에 발견된 질병이 2020년에 들어서면서 대유행하게 되었다. 빠른 확산 속도, 치료제가 없는 질병, 미각, 후각을 상실시키고 폐 섬유화를 유발하는...
# 행복마법사&apos;s 지식 주머니
# https://blog.naver.com/goodmyway
# 20220725
# -----------------------------
# 코로나 19 확진 후기
# https://blog.naver.com/l0641?Redirect=Log&logNo=222841057417
# 지금으로부터 2일 전, 코로나에 확진됐다. 그래서 남겨보는 기록용 후기. 8월 2일 화요일(가족 확진... 코로나로 인해 제한되는 사항이 너무 많지만, 면접을 보고 1주일은 편히 쉬려고 했기에 뜻밖에 보상이다....
# THIS PATH
# https://blog.naver.com/l0641
# 20220806
# -----------------------------
# 몰디브 코로나19 동향 관련 안내
# https://blog.naver.com/redcapstory?Redirect=Log&logNo=222844584507
# 안녕하세요, 레드캡투어 출장 담당자입니다 8/5일 주 스리랑카 대한민국 대사관에서 공지한 몰디브 코로나19 동향 관련 안내드릴께요! 몰디브 코로나19 동향 스리랑카 대사관 ㅇ 3.13(일) 몰디브...
# 레드캡투어 공식 블로그
# https://blog.naver.com/redcapstory
# 20220810
# -----------------------------
# 코로나 생활비지원금  중위소득기준 알아보기
# https://blog.naver.com/mayo51?Redirect=Log&logNo=222818196055
# 안녕하세요 재테크 긍정 긍정 마인드를 전달해드리는 나봄입니다:) 요즘 코로나 확진자 증가로 뉴스나 기사가 떠들썩하구요 회사에서도 종종 코로나 확진되시는 분들이 있어 위드코로나인 것이...
# 봄날의재테크라이프
# https://blog.naver.com/mayo51
# 20220719
# -----------------------------
# [주간일기] 빨리 지나가는 야속한 시간과 코로나 ㅜ
# https://blog.naver.com/ivbara?Redirect=Log&logNo=222827169429
# 코로나 때문에 사람이 가장 없을 법한 곳을 “해운대”에서 찾기ㅋ 우리가 간 곳은 해운대... 보자마자 곱창을 생각나게 하던데 그래서 담날 저녁메뉴가 곱창이 되었다지… 코로나가 오기 전 2019년쯤이 마지막...
# 아름답게 살자
# https://blog.naver.com/ivbara
# 20220724
# -----------------------------
# 7월 셋째주 일상 기록 :: 코로나 퇴원/친구 결혼식/직장인 점심...
# https://blog.naver.com/keb9889?Redirect=Log&logNo=222840064467
# 7월 셋째주 일상 기록 금요일까지 코로나로 격리하다가 토요일부터 해제✨ 해제 후 첫날... 후 코로나 확진까지 겹쳐 2주만에 회사 출근 코로나 입원 때 생긴 양쪽팔의 주사멍이 점점 심해지는 중ㅋㅋㅋ 이것도...
# 두 자매의 관심을 담아낸 공간
# https://blog.naver.com/keb9889
# 20220805
# -----------------------------
# 17세 이하·미접종군 코로나19 재감염에 취약
# https://blog.naver.com/eunyo20?Redirect=Log&logNo=222845627470
# 17세 이하 및 미접종군이 코로나19 재감염에 취약한 것으로 나타났다. 또한 백신 접종 횟수가... 7월 기준 코로나19 백신 미접종군이 약 12%임에도 불구하고 7월 2회감염 추정사례 중 미접종군은 약 50%로...
# 바이오가 세계를 바꾼다
# https://blog.naver.com/eunyo20
# 20220811
# -----------------------------
# 코로나 격리 후 기침모드
# https://blog.naver.com/noproblem3?Redirect=Log&logNo=222816224933
# 7월 15일로 다시금 자유를 찾았지만 잔기침과 무기력 등등으로 아직 코로나에 갇혀있다 입맛없음 무기력... 나의 코로나 덕분에 유일하게 살아남은 구피 살아남았어 칭찬해 마지막잎새 그런느낌인건가 끊임없이...
# #그녀의소반
# https://blog.naver.com/noproblem3
# 20220717
# -----------------------------
# 코로나 '확찐자’ 주목! 슬기로운 한식생활
# https://blog.naver.com/humc_health?Redirect=Log&logNo=222747147601
# 코로나 '확찐자’ 주목! 슬기로운 한식생활 통계청 자료에 따르면 최근 코로나19로 활동량이 줄어들며 코로나19 이전 33.8%였던 비만율이 코로나19 이후 38.3%로 4.5%나 증가했는데요. 이런 현상을 두고 급하게 살이...
# 한림대학교의료원(Hallym University Medical Center)
# https://blog.naver.com/humc_health
# 20220526
# -----------------------------
# 나도 걸렸다! 코로나 후각 상실, 생리 불순 등 요즘 코로나 증상
# https://blog.naver.com/seriring430?Redirect=Log&logNo=222838903315
# 처음 코로나가 퍼지고 무서운 확산세를 이어가던 때, 거리두기가 강화되고 사적 모임을 전부 취소하던 때, 거리두기가 해제되고 다시금 확진자가 터졌을 때, 그리고 남자친구가 코로나에 걸린 상태에서 뽀뽀...
# 세리링의 프라이빗 다이어링
# https://blog.naver.com/seriring430
# 20220803
# -----------------------------
# 7월에 코로나 걸린 헤요미 - 자가격리, 초기 증상, 동작구...
# https://blog.naver.com/khy2106?Redirect=Log&logNo=222833041517
# 사실 근 2주 동안 나한테 굉장히 다이나믹한 일이 많이 일어났었는데, 그중 하나가 바로 코로나... 어쨌든 오늘은, 근황+ 시리즈의 넘버 원이라고 할 수 있는 7월의 코로나에 대해 먼저 이야기해 보고자 한다. 7월...
# 코딩하는 헤요미
# https://blog.naver.com/khy2106
# 20220728
# -----------------------------
# (코로나확진/입덧/산후조리원 예약/그간 일상)
# https://blog.naver.com/kpwee?Redirect=Log&logNo=222849848887
# : 임신 6주차 (코로나 확진) 하와이에서 다녀온 이틀 뒤 갑자기 열이 확~오르더니 몸살인지 아프기 시작. 이게 코로나인지, 임신 때문인지 모르니.. 약 처방 받을 겸 산부인과에 갔다. 37도 이상이라 병원에서...
# 푸파의 청춘일기
# https://blog.naver.com/kpwee
# 20220816
# -----------------------------
# 드디어 걸린 코로나 , 증상 및 후각상실로 인한 우울감
# https://blog.naver.com/meinereise?Redirect=Log&logNo=222847854951
# 인후통, 미칠듯이 나오는 기침, 입맛 없음, 후각 상실 열 이 안 난다는 것 빼고는 너무나 코로나... 그게 코로나였는지 아니면 진짜 그냥 심한 감기였는지는 아직도 모르고 영원히 모를듯... 그 이후로 3월...
# Hello, World?
# https://blog.naver.com/meinereise
# 20220814
# -----------------------------
# 아이 코로나 확진 경과기록(2): 열나고부터 5일~9일차...
# https://blog.naver.com/bgrace?Redirect=Log&logNo=222845012424
# 하아,,,,엄마가 코로나 양성 나오면, 너 엄마랑 뽀뽀 못하는거 일주일 더 연장될 수도 있다고. 그래도... 코로나 자가격리 기간을 무사히 지내느라 진짜 수고 많았다.(kf94마스크 쓰고 실내에서 지내는게 답답했다...
# ☆The purpose driven life☆
# https://blog.naver.com/bgrace
# 20220810
# -----------------------------
# 코로나 격리 6일째 - 아직 아픕니다.
# https://blog.naver.com/3rdtop?Redirect=Log&logNo=222829529992
# 코로나 겸겸돼서 격리된지 6일차입니다. 내일 자정을 기해서 격리가 해제됩니다. 그 다음날 출근합니다.... 코로나 감염돼서 처방받은 약을 인터넷에 검색해 봐습니다. - 사진출처 : 네이버 이미지 이약의 이름은...
# 땡초현각의 쓸데없는 마음공부
# https://blog.naver.com/3rdtop
# 20220726
# -----------------------------
# 29~30주 임산부 코로나 확진 격리 생활
# https://blog.naver.com/lovealive?Redirect=Log&logNo=222809533203
# 수액 다 맞고 계속 몸이 너무 힘든상태에서 남편에게 전화가 옴 여보 나 코로나 확진이고, 7일 격리해야 된대 여보도 검사해야 된대 응? 바로 수지미래산부인과 1층에 가서 코로나검사진행 코로나 양성입니다...
# 토실이의 주부생활
# https://blog.naver.com/lovealive
# 20220713
# -----------------------------
# [40개월아기] 코로나 격리 1일차 / 4살아기 확진 초기증상
# https://blog.naver.com/byunhj213?Redirect=Log&logNo=222821180534
# 안녕하세요 쁨이맘 변니에요 요즘 다시 코로나가 확산세죠 확진자도 급격히 증가하는 추세잖아요 이제 일상으로 돌아가나 싶었는데..망할코로나 네...저희집에도 찾아왔어요 안걸릴것만 같았던 코로나시키...
# 쁨이네일상
# https://blog.naver.com/byunhj213
# 20220720
# -----------------------------
# '코로나19' 를 떨치고 복분자 챙기기
# https://blog.naver.com/alla12?Redirect=Log&logNo=222809905189
# '코로나19' 를 떨치고 복분자 챙기기 '코로나19' 확진자가 날로 늘어납니다. 월요일 10명, 화요일 34명, 오늘 24명, 안전 안내문자 내용입니다. 읍내에 먹거리 몇 종 사러갈 것을 포기합니다. 4차 예방 접종일이 3월...
# 산자 행운이
# https://blog.naver.com/alla12
# 20220713
# -----------------------------
# 계절성 코로나 바이러스에 대한 면역은 오래 남는다?
# https://blog.naver.com/jjy0501?Redirect=Log&logNo=222827465823
# Credit: Published in Cell Host &amp; Microbe, July 2022) 코로나 19 대유행 초기부터 계절성 코로나 바이러스 감염에 의한 면역이 코로나 19 감염에서 어떤 역할을 하는지는 과학자들의 큰 관심사였습니다....
# 고든의 블로그
# https://blog.naver.com/jjy0501
# 20220801
# -----------------------------
# [코로나일상] 코로나 3일~4일차/극심한 인후통으로 고통받는 중...
# https://blog.naver.com/eundor1004?Redirect=Log&logNo=222841072011
# 아이랑 같이 코로나로 격리중인데 아이는 코로나 초반에 2일 정도 고열나서 열 내린 뒤로는 다른 증상이 1도 없어서 코로나 증상 적는게 무의미할 정도. 일단은 병원에서 받아 온 약은 항생제가 있어서 4일치 다...
# 쁘띠와함께하는매일여행
# https://blog.naver.com/eundor1004
# 20220806
# -----------------------------
# 코로나간식 물떡국
# https://blog.naver.com/not1004seon?Redirect=Log&logNo=222826656002
# #코로나한끼 #코로나격리중 #코로나아점 #코로나간식 #냉장고파먹기 아침 밥먹기 매일 전쟁... 돌아서면 점심 전쟁... 이를 막기위해 아점!! 우리집 아점은 따님이 원하는 걸 잘 준다.그래서 물떡도 먹고 싶고...
# 마녀의 놀이터
# https://blog.naver.com/not1004seon
# 20220724
# -----------------------------
# 코로나 확진자 지원금 :: 신청 마지막 정리했습니다
# https://blog.naver.com/topjoys?Redirect=Log&logNo=222717653576
# 그동안 코로나와 관련된 여러 지원금을 소개 해드렸습니다. 2-3월 사이에 상당히 많은 확진자가 발생하면서 이 코로나 확진자 지원금 신청에도 다양한 변화가 있었습니다. 특히 가장 크게 달라진 점은 금액이고...
# 핀퐁 : 당신의 경제 나침반
# https://blog.naver.com/topjoys
# 20220501
# -----------------------------
# 코로나엔데믹시대! OO 뜬다! 여기어때&amp;야놀자 광고 비교
# https://medico.tistory.com/1239
# 코로나가 조금씩 잠잠해지는 시기의 산업 변화에 대한 포스팅입니다. 여러 놀라운 신문기사들/산업 변화들. 최근 찾아보고 재밌어서 정리한 내용입니다. 목차 1. 코로나 엔데믹 상황으로 인한 산업별...
# 메디코노믹스 - 재테크, 블로그, 의료에서 의료경영 관련까지
# https://medico.tistory.com/
# 20220706
# -----------------------------
# 출국 전 코로나확진, 해외에서 코로나 확진
# https://blog.naver.com/mokbs2?Redirect=Log&logNo=222834887866
# 전 코로나확진 목적지국 코로나 관련 서류에 대해서 확인을 해야 합니다. 격리해제로 출국을 한다고 해도 코로나 확진일 기준 10일을 경과하고 귀국해야 합니다. *10월1일 확진. 10월8일 출국했다면 적어도...
# 퍼플트립
# https://blog.naver.com/mokbs2
# 20220730
# -----------------------------
# [현장소식 ZONE] '슬기로운 포스트 코로나 생활' 인터뷰 1부...
# https://blog.naver.com/gne_education?Redirect=Log&logNo=222850524232
# Post Corona Post(이후)와 코로나19의 합성어로, 코로나 이후 다가온 새로운 시대를 일컫습니다. 전면 원격수업 전환, 급식 중단과 같은 급격한 교육현장의 변화를 거쳐 포스트 코로나를 맞은 지금. 실제 학교...
# 경상남도교육청
# https://blog.naver.com/gne_education
# 20220817
# -----------------------------
# 집콕하던 모녀도 피하지 못한 코로나확진/호흡곤란/119...
# https://blog.naver.com/kkangjsgood?Redirect=Log&logNo=222841803978
# 안녕하세요:) 네,,, 코로나 걸릴까봐 몇 년째 집콕만 하던 저희 모녀.. 코로나 확진받았습니다.. 7월마지막날 저녁부터 갑자기 느닷없이 심한 기침과 몸살이 시작돴어요 저희 세 식구는 원체 집,동네 유모차산책...
# 디아맘과 함께하는 건강한세상
# https://blog.naver.com/kkangjsgood
# 20220807
# -----------------------------
# 코로나 약처방 및 증상순서 3일차(인후통, 기침, 가래, 설사...
# https://blog.naver.com/kimsaeronl?Redirect=Log&logNo=222831602961
# 코로나 자가키트 양성 및 확진 1-2일차 증상은 포스팅 가장 밑쪽을 참고하세요! 22.7.27.수. - 코로나 재택치료 3일차 증상 순서 : 인후통, 기침가래, 설사, 구역감 오늘은 확진 3일차 어제보다도 증상이...
# 여리로리
# https://blog.naver.com/kimsaeronl
# 20220727
# -----------------------------
# 코로나에 확진됐다. 처음으로...
# https://blog.naver.com/nabibelle?Redirect=Log&logNo=222828501743
# 지난주 금요일 아침 코로나에 확진됐다. 전날 밤부터 몸살 기운이 있었는데 당일 아침엔 열까지 나서 일어나기도 힘들었다. 자가진단이고 뭐고 이건 코로나라는 확신이 들었다. 병원 진료시간이 시작되기도...
# 나비의 꽁냥꽁냥 사랑방
# https://blog.naver.com/nabibelle
# 20220725
# -----------------------------
# 코로나19 인가? 감기인가?
# https://blog.naver.com/jaipy2ya?Redirect=Log&logNo=222828305435
# (미칠 것 같은 두통과 무기력증도 사라져버렸음ㅋㅋ) 목소리가 변하니깐 다들 코로나19 걸린 거라고... 혹시 코로나19일 수 있으니 해달라고 했다. (친절하고 하나하나 설명해주시고 덜 아프게 살살 하시던데...
# Whatever you want, is
# https://blog.naver.com/jaipy2ya
# 20220725
# -----------------------------
# 승진탈락/대직자휴가/코로나후유증 진행 중
# https://blog.naver.com/meinv0505?Redirect=Log&logNo=222834560605
# 필수 교육 시간도 코로나 때문에 집에 있느라 듣지 못해 채우지 못한 상황이었기 때문이다. 며칠 전... 키즈노트 속 아이 중요한 보고서 결재 올리기 코로나로 오래 격리하다가 다시 출근하니 월말에 가까워서...
# H와 함께하는 일상
# https://blog.naver.com/meinv0505
# 20220730
# -----------------------------
# 수집완료
